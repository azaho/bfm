# %%
import wandb
import os
import torch
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
from train_utils import update_dir_name, get_default_configs
font_path = 'analyses/font_arial.ttf'
fm.fontManager.addfont(font_path)
plt.rcParams['font.family'] = 'Arial'
plt.rcParams.update({'font.size': 12})

# Get wandb run history
api = wandb.Api()
wandb_path = os.path.join("..", "wandb")

# %%
training_config, model_config, cluster_config = get_default_configs(random_string="X", wandb_project="btbank_tests")

# %%
random_strings = ["CONT_FBI1", "CONT_FBI2", "CONT_FBI3"]


learning_rates = sorted([0.0015, 0.0021, 0.003, 0.0042, 0.006, 0.0084])
future_bin_idx = [1, 2, 3, 4]

spec_values = [0]#, 0]

condition_str = [f"{fbidx}_{lr}" for fbidx in future_bin_idx for lr in learning_rates]

# Initialize histories dict
histories = {cs: [] for cs in condition_str}

# Generate all run IDs and collect histories
for cs in condition_str:
    for rs in random_strings:
        training_config['random_string'] = rs
        training_config['learning_rate'] = float(cs.split("_")[1])
        training_config['future_bin_idx'] = int(cs.split("_")[0])
        model_config['electrode_embedding']['spectrogram'] = spec_values[0]

        run_id = update_dir_name(model_config, training_config, cluster_config)
        
        runs = api.runs(f"andrii-mit/{cluster_config['wandb_project']}", filters={"display_name": run_id})
        if len(runs) > 0:
            run = runs[0]
            history = run.history()
            if '_step' not in history.columns:
                print(f"Run {run_id} has no '_step' column")
                continue
            n_epochs = 100
            if history['_step'].max() >= n_epochs:  # Only include if trained for full 100 epochs
                histories[cs].append(history)
            else:
                print(f"Run {run_id} did not train for full {n_epochs} epochs ({history['_step'].max()} epochs)")

for cs in condition_str:
    print(f"condition {cs}: {len(histories[cs])} runs")
# Out:
# Run M_nst8_dm192_nh12_nl5_5_nSP_fb2_lr0.0084_rCONT_FBI2 did not train for full 100 epochs (68 epochs)
# Run M_nst8_dm192_nh12_nl5_5_nSP_fb2_lr0.0084_rCONT_FBI3 did not train for full 100 epochs (82 epochs)
# condition 1_0.0015: 3 runs
# condition 1_0.0021: 3 runs
# condition 1_0.003: 3 runs
# condition 1_0.0042: 3 runs
# condition 1_0.006: 3 runs
# condition 1_0.0084: 3 runs
# condition 2_0.0015: 3 runs
# condition 2_0.0021: 3 runs
# condition 2_0.003: 3 runs
# condition 2_0.0042: 3 runs
# condition 2_0.006: 3 runs
# condition 2_0.0084: 1 runs
# condition 3_0.0015: 3 runs
# condition 3_0.0021: 3 runs
# condition 3_0.003: 3 runs
# condition 3_0.0042: 3 runs
# condition 3_0.006: 3 runs
# condition 3_0.0084: 3 runs
# condition 4_0.0015: 3 runs
# condition 4_0.0021: 3 runs
# condition 4_0.003: 3 runs
# condition 4_0.0042: 3 runs
# condition 4_0.006: 3 runs
# condition 4_0.0084: 3 runs

# %%
len(h)
# Out:
# 10

# %%
n_epochs
# Out:
# 100

# %%
metrics = ['train_loss', 'test_loss', 'eval_auroc/average_speech', 'eval_auroc/average_volume', 'eval_auroc/average_gpt2_surprisal', 'eval_auroc/average_word_part_speech']
metric_names = ['Training Loss', 'Test Loss', 'Decoding Speech AUROC', 'Decoding Volume AUROC', 'Decoding GPT2 Surprisal AUROC', 'Decoding Word Part Speech AUROC']
n_last_measurements = 3

# Initialize results dictionary
results = {cs: {metric: [] for metric in metrics} 
          for cs in condition_str}

# Calculate means for each run
for cs in condition_str:
    for history in histories[cs]:
        for metric in metrics:
            h = np.array(list(history[metric].iloc))
            h = h[~np.isnan(h)]
            results[cs][metric].append(h[-n_last_measurements:].mean())

# Print results
for cs in condition_str:
    print(f"\ncs {cs}:")
    for metric in metrics:
        values = results[cs][metric]
        if values:
            mean = sum(values) / len(values)
            print(f"{metric}: {mean:.4f} (across {len(values)} runs)")
# Out:
# cs 1_0.0015:
# train_loss: 0.0058 (across 3 runs)
# test_loss: 0.0085 (across 3 runs)
# eval_auroc/average_speech: 0.6877 (across 3 runs)
# eval_auroc/average_volume: 0.5535 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5552 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5180 (across 3 runs)
#
# cs 1_0.0021:
# train_loss: 0.0066 (across 3 runs)
# test_loss: 0.0075 (across 3 runs)
# eval_auroc/average_speech: 0.7001 (across 3 runs)
# eval_auroc/average_volume: 0.5578 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5530 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5167 (across 3 runs)
#
# cs 1_0.003:
# train_loss: 0.0415 (across 3 runs)
# test_loss: 0.4656 (across 3 runs)
# eval_auroc/average_speech: 0.7005 (across 3 runs)
# eval_auroc/average_volume: 0.5651 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5543 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5172 (across 3 runs)
#
# cs 1_0.0042:
# train_loss: 0.0048 (across 3 runs)
# test_loss: 0.0058 (across 3 runs)
# eval_auroc/average_speech: 0.6865 (across 3 runs)
# eval_auroc/average_volume: 0.5609 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5510 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5192 (across 3 runs)
#
# cs 1_0.006:
# train_loss: 0.0852 (across 3 runs)
# test_loss: 0.0471 (across 3 runs)
# eval_auroc/average_speech: 0.6764 (across 3 runs)
# eval_auroc/average_volume: 0.5614 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5515 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5165 (across 3 runs)
#
# cs 1_0.0084:
# train_loss: 3.2266 (across 3 runs)
# test_loss: 0.4091 (across 3 runs)
# eval_auroc/average_speech: 0.6611 (across 3 runs)
# eval_auroc/average_volume: 0.5579 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5500 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5172 (across 3 runs)
#
# cs 2_0.0015:
# train_loss: 0.0402 (across 3 runs)
# test_loss: 0.0813 (across 3 runs)
# eval_auroc/average_speech: 0.7356 (across 3 runs)
# eval_auroc/average_volume: 0.5868 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5556 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5244 (across 3 runs)
#
# cs 2_0.0021:
# train_loss: 0.0319 (across 3 runs)
# test_loss: 0.0521 (across 3 runs)
# eval_auroc/average_speech: 0.7683 (across 3 runs)
# eval_auroc/average_volume: 0.6207 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5580 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5211 (across 3 runs)
#
# cs 2_0.003:
# train_loss: 0.0248 (across 3 runs)
# test_loss: 0.0436 (across 3 runs)
# eval_auroc/average_speech: 0.7782 (across 3 runs)
# eval_auroc/average_volume: 0.6183 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5633 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5250 (across 3 runs)
#
# cs 2_0.0042:
# train_loss: 0.0306 (across 3 runs)
# test_loss: 0.0465 (across 3 runs)
# eval_auroc/average_speech: 0.7772 (across 3 runs)
# eval_auroc/average_volume: 0.6089 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5602 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5182 (across 3 runs)
#
# cs 2_0.006:
# train_loss: 0.1257 (across 3 runs)
# test_loss: 0.0675 (across 3 runs)
# eval_auroc/average_speech: 0.7657 (across 3 runs)
# eval_auroc/average_volume: 0.6108 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5581 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5138 (across 3 runs)
#
# cs 2_0.0084:
# train_loss: 0.0941 (across 1 runs)
# test_loss: 0.4434 (across 1 runs)
# eval_auroc/average_speech: 0.7536 (across 1 runs)
# eval_auroc/average_volume: 0.6180 (across 1 runs)
# eval_auroc/average_gpt2_surprisal: 0.5542 (across 1 runs)
# eval_auroc/average_word_part_speech: 0.5229 (across 1 runs)
#
# cs 3_0.0015:
# train_loss: 0.0761 (across 3 runs)
# test_loss: 0.1187 (across 3 runs)
# eval_auroc/average_speech: 0.7335 (across 3 runs)
# eval_auroc/average_volume: 0.5837 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5542 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5135 (across 3 runs)
#
# cs 3_0.0021:
# train_loss: 0.0438 (across 3 runs)
# test_loss: 0.0735 (across 3 runs)
# eval_auroc/average_speech: 0.7778 (across 3 runs)
# eval_auroc/average_volume: 0.6290 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5579 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5190 (across 3 runs)
#
# cs 3_0.003:
# train_loss: 0.0391 (across 3 runs)
# test_loss: 0.0708 (across 3 runs)
# eval_auroc/average_speech: 0.7750 (across 3 runs)
# eval_auroc/average_volume: 0.6259 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5527 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5194 (across 3 runs)
#
# cs 3_0.0042:
# train_loss: 0.0519 (across 3 runs)
# test_loss: 0.0811 (across 3 runs)
# eval_auroc/average_speech: 0.7852 (across 3 runs)
# eval_auroc/average_volume: 0.6231 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5581 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5182 (across 3 runs)
#
# cs 3_0.006:
# train_loss: 0.1903 (across 3 runs)
# test_loss: 0.0938 (across 3 runs)
# eval_auroc/average_speech: 0.7520 (across 3 runs)
# eval_auroc/average_volume: 0.6136 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5529 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5197 (across 3 runs)
#
# cs 3_0.0084:
# train_loss: 0.0719 (across 3 runs)
# test_loss: 0.0887 (across 3 runs)
# eval_auroc/average_speech: 0.7560 (across 3 runs)
# eval_auroc/average_volume: 0.6133 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5566 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5174 (across 3 runs)
#
# cs 4_0.0015:
# train_loss: 0.0993 (across 3 runs)
# test_loss: 0.1567 (across 3 runs)
# eval_auroc/average_speech: 0.7147 (across 3 runs)
# eval_auroc/average_volume: 0.5800 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5462 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5115 (across 3 runs)
#
# cs 4_0.0021:
# train_loss: 0.0556 (across 3 runs)
# test_loss: 0.0997 (across 3 runs)
# eval_auroc/average_speech: 0.7625 (across 3 runs)
# eval_auroc/average_volume: 0.6112 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5529 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5154 (across 3 runs)
#
# cs 4_0.003:
# train_loss: 0.0551 (across 3 runs)
# test_loss: 0.1023 (across 3 runs)
# eval_auroc/average_speech: 0.7724 (across 3 runs)
# eval_auroc/average_volume: 0.6220 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5563 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5170 (across 3 runs)
#
# cs 4_0.0042:
# train_loss: 0.0644 (across 3 runs)
# test_loss: 0.0939 (across 3 runs)
# eval_auroc/average_speech: 0.7707 (across 3 runs)
# eval_auroc/average_volume: 0.6184 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5501 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5165 (across 3 runs)
#
# cs 4_0.006:
# train_loss: 0.0620 (across 3 runs)
# test_loss: 0.1940 (across 3 runs)
# eval_auroc/average_speech: 0.7495 (across 3 runs)
# eval_auroc/average_volume: 0.6196 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5466 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5192 (across 3 runs)
#
# cs 4_0.0084:
# train_loss: 0.0903 (across 3 runs)
# test_loss: 0.1446 (across 3 runs)
# eval_auroc/average_speech: 0.7508 (across 3 runs)
# eval_auroc/average_volume: 0.6046 (across 3 runs)
# eval_auroc/average_gpt2_surprisal: 0.5490 (across 3 runs)
# eval_auroc/average_word_part_speech: 0.5169 (across 3 runs)

# %%
# Set error bar type ('std' for standard deviation or 'sem' for standard error of mean)
error_type = 'sem'

fig, axes = plt.subplots(1, len(metrics), figsize=(3.5*len(metrics), 6))

for i, metric in enumerate(metrics):
    for fbi_idx, fbi in enumerate(future_bin_idx):
        means = []
        errors = []
        ps = []
        all_values = []
        all_ps = []
        
        # Calculate base x position for this batch size group
        base_x = fbi_idx * (len(learning_rates) + 1)  # +1 for spacing between groups
        
        # Get data for each learning rate within this batch size
        for lr_idx, lr in enumerate(learning_rates):
            cs = f"{fbi}_{lr}"  # Reconstruct condition string
            values = results[cs][metric] if cs in results else []
            
            if values:
                means.append(np.mean(values))
                if error_type == 'std':
                    errors.append(np.std(values))
                else:  # sem
                    errors.append(np.std(values) / np.sqrt(len(values)))
                
                x_ind = base_x + lr_idx
                ps.append(x_ind)
                
                # Store individual points
                all_values.extend(values)
                all_ps.extend([x_ind] * len(values))
        
        # Plot individual points with some jitter and transparency
        jitter = 0.1
        axes[i].scatter(
            [p + np.random.uniform(-jitter, jitter) for p in all_ps],
            all_values,
            alpha=0.3,
            color=f'C{fbi_idx}',
            zorder=1
        )
        
        # Plot mean and error bars for this batch size group
        if means:  # Only plot if we have data
            error_label = f'pred future {fbi} bin'
            axes[i].errorbar(ps, means, yerr=errors, marker='o', capsize=5, 
                        color=f'C{fbi_idx}', zorder=2, label=error_label,
                        linewidth=2)
    
    # Set x-ticks and labels for learning rates
    all_x_ticks = []
    all_x_labels = []
    for fbi_idx, fbi in enumerate(future_bin_idx):
        base_x = fbi_idx * (len(learning_rates) + 1)
        all_x_ticks.extend([base_x + i for i in range(len(learning_rates))])
        all_x_labels.extend([f"{lr}" for lr in learning_rates])
    
    axes[i].set_xticks(all_x_ticks, all_x_labels, rotation=90)
    axes[i].set_xlabel('Learning Rate')
    axes[i].set_title(metric_names[i], color='black', fontsize=12)
    axes[i].grid(True)
    if i==0: axes[i].legend()

axes_lime = [(0, 2), (0, 2), (0.5, .9), (0.5, .9), (0.5, .9), (0.5, .9)]
for i, ax in enumerate(axes):
    ax.set_ylim(axes_lime[i])

plt.suptitle(f'Performance after {n_epochs} epochs of training on btbank-lite:', color='black', fontsize=14, y=0.95)
plt.tight_layout()
plt.savefig(f'analyses/exp_fbi_{random_strings[0].lower()}_spec{spec_values[0]}.pdf', bbox_inches='tight', dpi=300)
plt.show()
