# %%
import torch
import wandb, os, json
import time

from muon import Muon
from model_model import TransformerModel
from model_electrode_embedding import ElectrodeEmbedding_Learned, ElectrodeEmbedding_NoisyCoordinate, ElectrodeEmbedding_Learned_CoordinateInit, ElectrodeDataEmbeddingFFT, ElectrodeDataEmbedding

from dataset import load_dataloaders
from evaluation_btbench import FrozenModelEvaluation_SS_SM
from train_utils import log, update_dir_name, update_random_seed, convert_dtypes, parse_configs_from_args, get_default_configs, get_shared_memory_info

training_config, model_config, cluster_config = get_default_configs(random_string="TEMP", wandb_project="")
training_config.update({
    'train_subject_trials': [("btbank3", 0)],
    'eval_subject_trials': [("btbank3", 0)],
})

#parse_configs_from_args(training_config, model_config, cluster_config)
dir_name = update_dir_name(model_config, training_config, cluster_config)
update_random_seed(training_config)
cluster_config['wandb_name'] = cluster_config['dir_name']
log(f"Directory name: {dir_name}", priority=0)

if len(cluster_config['wandb_project'])==0: wandb = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
log(f"Using device: {device}", priority=0)


log(f"Loading dataloaders...", priority=0)
n_samples = model_config['max_n_timebins'] * model_config['sample_timebin_size']
all_subjects, train_dataloader, test_dataloader = load_dataloaders(
    training_config['train_subject_trials'], training_config['eval_subject_trials'], training_config['p_test'], 
    model_config['sample_timebin_size'], model_config['max_n_timebins'], training_config['data_dtype'], 
    training_config['batch_size'],
    num_workers_dataloaders=cluster_config['num_workers_dataloaders'], 
    cache=cluster_config['cache_subjects'], allow_corrupted=False,
    prefetch_factor=cluster_config['prefetch_factor'],
)

eval_subject_trials = [(all_subjects[subject_identifier], trial_id) for subject_identifier, trial_id in training_config['eval_subject_trials']]
evaluation = FrozenModelEvaluation_SS_SM(
    ['speech', 'volume', 'gpt2_surprisal', 'word_part_speech'], eval_subject_trials, 
    training_config['data_dtype'], training_config['batch_size'] * 2, # Can have a bigger batch size here if that speeds things up
    num_workers_eval=cluster_config['num_workers_eval'],
    prefetch_factor=cluster_config['prefetch_factor'],
    feature_aggregation_method=cluster_config['eval_aggregation_method'],
)
# Out:
# [22:14:12 gpu 14.4G ram 7.6G] (0) Directory name: M_nst1_dm192_nh12_nl5_5_eaM_eeL_fb1_lr0.003_rTEMP
# [22:14:12 gpu 14.4G ram 7.6G] (0) Using device: cuda
# [22:14:12 gpu 14.4G ram 7.6G] (0) Loading dataloaders...
# [22:14:12 gpu 14.4G ram 7.6G] (1)     loading subject btbank3...
# [22:14:12 gpu 14.4G ram 7.6G] (1)     loading dataset for btbank3_0...
# [22:14:51 gpu 14.4G ram 10.9G] (1)     finished loading dataset for btbank3_0

# %%
model = TransformerModel(
    model_config['transformer']['d_model'],  
    n_layers_electrode=model_config['transformer']['n_layers_electrode'], 
    n_layers_time=model_config['transformer']['n_layers_time'],
    n_heads=model_config['transformer']['n_heads'],
    use_cls_token=model_config['transformer']['use_cls_token']
).to(device, dtype=model_config['dtype'])

if model_config['electrode_embedding']['type'] == 'learned' or model_config['electrode_embedding']['type'] == 'zero':
    electrode_embeddings = ElectrodeEmbedding_Learned(
        model_config['transformer']['d_model'], 
        embedding_dim=model_config['electrode_embedding']['embedding_dim'],
        embedding_requires_grad=model_config['electrode_embedding']['type'] != 'zero'
    )
elif model_config['electrode_embedding']['type'] == 'coordinate_init':
    electrode_embeddings = ElectrodeEmbedding_Learned_CoordinateInit(
        model_config['transformer']['d_model'], 
        embedding_dim=model_config['electrode_embedding']['embedding_dim']
    )
elif model_config['electrode_embedding']['type'] == 'noisy_coordinate':
    electrode_embeddings = ElectrodeEmbedding_NoisyCoordinate(
        model_config['transformer']['d_model'], 
        coordinate_noise_std=model_config['electrode_embedding']['coordinate_noise_std'],
        embedding_dim=model_config['electrode_embedding']['embedding_dim']
    )
else:
    raise ValueError(f"Invalid electrode embedding type: {model_config['electrode_embedding']['type']}")
electrode_embeddings = electrode_embeddings.to(device, dtype=model_config['dtype'])

if model_config['electrode_embedding']['spectrogram']:
    electrode_data_embeddings = ElectrodeDataEmbeddingFFT(
        electrode_embeddings, model_config['sample_timebin_size'], 
        max_frequency=model_config['max_frequency']
    ).to(device, dtype=model_config['dtype'])
else:
    electrode_data_embeddings = ElectrodeDataEmbedding(
        electrode_embeddings, model_config['sample_timebin_size'], 
        overall_sampling_rate=next(iter(all_subjects.values())).get_sampling_rate(0) # XXX remove this once figured out how to be flexible here regarding the sampling rate
    ).to(device, dtype=model_config['dtype'])

for subject in all_subjects.values():
    this_subject_trials = [trial_id for (sub_id, trial_id) in training_config['train_subject_trials'] if sub_id == subject.subject_identifier]
    electrode_data_embeddings.add_subject(subject, subject.get_sampling_rate(this_subject_trials[0]))
    log(f"Adding subject {subject.subject_identifier} to electrode data embeddings...", priority=0)
    if model_config['init_normalization']:
        for trial_id in this_subject_trials:
            log(f"Initializing normalization for subject {subject.subject_identifier} trial {trial_id}...", priority=1, indent=1)
            electrode_data_embeddings.initialize_normalization(subject, trial_id, init_normalization_window_to=int(subject.get_sampling_rate(trial_id) * 60 * 5))
electrode_data_embeddings = electrode_data_embeddings.to(device, dtype=model_config['dtype']) # moving to device again to ensure the new parameters are on the correct device



all_params = list(model.parameters()) + list(electrode_data_embeddings.parameters())
n_model_params = sum(p.numel() for p in model.parameters())
n_embed_params = sum(p.numel() for p in electrode_data_embeddings.parameters())
log(f"Model parameters: {n_model_params:,}", priority=0)
log(f"Embedding parameters: {n_embed_params:,}", priority=0)
log(f"Total parameters: {n_model_params + n_embed_params:,}", priority=0)
model_config['n_params'] = {
    'model': n_model_params,
    'embeddings': n_embed_params,
    'total': n_model_params + n_embed_params
}

optimizers = []
if training_config['optimizer'] == 'Muon':
    matrix_params = [p for p in all_params if p.ndim >= 2]
    other_params = [p for p in all_params if p.ndim < 2]

    optimizers.append(Muon(matrix_params, lr=training_config['learning_rate'], momentum=0.95, nesterov=True, backend='newtonschulz5', backend_steps=5, weight_decay=training_config['weight_decay']))
    optimizers.append(torch.optim.AdamW(other_params, lr=training_config['learning_rate'], weight_decay=training_config['weight_decay']))
else:
    optimizers = [torch.optim.AdamW(all_params, lr=training_config['learning_rate'], weight_decay=training_config['weight_decay'])]
# Out:
# [22:15:05 gpu 14.4G ram 10.9G] (0) Adding subject btbank3 to electrode data embeddings...
# [22:15:05 gpu 14.4G ram 10.9G] (1)     Initializing normalization for subject btbank3 trial 0...
# [22:15:05 gpu 14.4G ram 10.9G] (0) Model parameters: 4,571,329
# [22:15:05 gpu 14.4G ram 10.9G] (0) Embedding parameters: 52,161
# [22:15:05 gpu 14.4G ram 10.9G] (0) Total parameters: 4,623,490

# %%
proj_type = None#'random_batch_nR' # None, 'random_batch', 'Norm'
dir_name = update_dir_name(model_config, training_config, cluster_config) + f'_proj_{proj_type}'

def calculate_loss_function(batch, subject_identifier, trial_id):
    electrode_embedded_data = electrode_data_embeddings.forward(subject_identifier, all_subjects[subject_identifier].get_electrode_indices(trial_id), 
                                                             batch, max_n_electrodes=model_config['max_n_electrodes'])
    
    batch_size, n_electrodes, n_timebins, d_model = electrode_embedded_data.shape

    permutation = torch.randperm(n_electrodes)
    electrode_embedded_data = electrode_embedded_data[:, permutation]

    n_electrodes_per_stream = int(n_electrodes * training_config['p_electrodes_per_stream'])
    o1_e, o1_t = model(electrode_embedded_data[:, :n_electrodes_per_stream, :, :]) # shape: (batch_size, n_timebins, d_model)
    o2_e, o2_t = model(electrode_embedded_data[:, -n_electrodes_per_stream:, :, :]) # shape: (batch_size, n_timebins, d_model)

    if proj_type == 'random_batch':
        random_matrix = torch.randn(d_model, d_model, device=model.device, dtype=torch.float32)
        q, r = torch.linalg.qr(random_matrix)  # Get orthogonal matrix via QR decomposition
        random_matrix = q.to(model.device, dtype=model_config['dtype'])  # q is an orthogonal matrix
    elif proj_type == 'random_batch_nR':
        random_matrix = torch.randn(d_model, d_model, device=model.device, dtype=model_config['dtype']) / (d_model ** 0.5)
    else:
        random_matrix = torch.eye(d_model, device=model.device, dtype=model_config['dtype'])
    o1_t = torch.matmul(o1_t, random_matrix)
    o2_t = torch.matmul(o2_t, random_matrix)
    o1_e = torch.matmul(o1_e, random_matrix)
    o2_e = torch.matmul(o2_e, random_matrix)
    
    similarity_1 = torch.matmul(o1_t[:, :-training_config['future_bin_idx']].permute(1, 0, 2), o2_e[:, training_config['future_bin_idx']:].permute(1, 2, 0)) * model.temperature_param
    expanded_arange = torch.arange(batch_size).unsqueeze(0).repeat(n_timebins-training_config['future_bin_idx'], 1).to(model.device, dtype=torch.long).reshape(-1)
    loss = torch.nn.functional.cross_entropy(similarity_1.view(-1, batch_size), expanded_arange)

    if training_config['symmetric_loss']:
        similarity_2 = torch.matmul(o2_t[:, :-training_config['future_bin_idx']].permute(1, 0, 2), o1_e[:, training_config['future_bin_idx']:].permute(1, 2, 0)) * model.temperature_param
        loss += torch.nn.functional.cross_entropy(similarity_2.view(-1, batch_size), expanded_arange)
        loss /= 2
    
    return {'contrastive': loss}

# %%
training_statistics_store = []
if wandb: 
    wandb.init(project=cluster_config['wandb_project'], name=cluster_config['wandb_name'], id=cluster_config['wandb_name'],
    config={"training_config": training_config, "model_config": model_config, "cluster_config": cluster_config}, settings=wandb.Settings(init_timeout=480))
for epoch_i in range(training_config['n_epochs']):
    epoch_start_time = time.time()
    model.train()

    # Main training loop
    epoch_losses = {}
    for batch_idx, (batch, (subject_identifiers, trial_ids)) in enumerate(train_dataloader):
        for optimizer in optimizers: optimizer.zero_grad()
        subject_identifier = subject_identifiers[0]
        trial_id = trial_ids[0].item()
        
        batch = batch.to(device, dtype=model_config['dtype'], non_blocking=True)
        loss_dict = calculate_loss_function(batch, subject_identifier, trial_id)

        for key, loss in loss_dict.items():
            if key not in epoch_losses: epoch_losses[key] = 0
            epoch_losses[key] += loss.item()

        loss = sum(loss_dict.values()) / len(loss_dict)
        loss.backward()
        for optimizer in optimizers: optimizer.step()

        training_statistics_store.append({
            'epoch': epoch_i+1,
            'batch': batch_idx+1,
            'subject_identifier': subject_identifier,
            'trial_id': trial_id,
            'batch_loss': loss.item(),
            'timestamp': time.time(),
            **{f"batch_{k}": v.item() for k, v in loss_dict.items()}
        })

        log(f"Epoch {epoch_i+1}/{training_config['n_epochs']}, Batch {batch_idx+1}/{len(train_dataloader)} ({subject_identifier}_{trial_id}), Loss: {loss.item():.4f}", priority=0)
    for key, loss in epoch_losses.items():
        epoch_losses[key] /= len(train_dataloader)

    # Evaluate the model
    model.eval()
    eval_results = {f"train_{k}": v for k, v in epoch_losses.items()}
    eval_results['train_loss'] = sum(epoch_losses.values()) / len(epoch_losses)
    with torch.no_grad():
        test_loss_dict = model.calculate_pretrain_test_loss(electrode_data_embeddings, test_dataloader, all_subjects, calculate_loss_function=calculate_loss_function)
        eval_results.update({f"test_{k}": v.item() for k, v in test_loss_dict.items()})
        eval_results['test_loss'] = sum(test_loss_dict.values()).item() / len(test_loss_dict)
        if (epoch_i+1) % cluster_config['eval_model_every_n_epochs'] == 0:
            evaluation_results_strings = evaluation.evaluate_on_all_metrics(model, electrode_data_embeddings, log_priority=1, quick_eval=True)
            eval_results.update(evaluation_results_strings)
        time_remaining = (time.time() - epoch_start_time) * (training_config['n_epochs'] - (epoch_i + 1))
        days = int(time_remaining // (24 * 3600))
        log(f"Estimated time remaining: {days}d, {time.strftime('%H:%M:%S', time.gmtime(time_remaining % (24 * 3600)))}", priority=0)
    if wandb: wandb.log(eval_results, step=epoch_i+1)
    print(eval_results)
    training_statistics_store[-1].update(eval_results)
if wandb: wandb.finish()
# Out:
# [22:15:06 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 1/20 (btbank3_0), Loss: 4.6562
# [22:15:06 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 2/20 (btbank3_0), Loss: 4.6562
# [22:15:06 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 3/20 (btbank3_0), Loss: 4.6562
# [22:15:07 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 4/20 (btbank3_0), Loss: 4.6250
# [22:15:07 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 5/20 (btbank3_0), Loss: 4.6250
# [22:15:07 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 6/20 (btbank3_0), Loss: 4.6250
# [22:15:07 gpu 14.4G ram 10.9G] (0) Epoch 1/100, Batch 7/20 (btbank3_0), Loss: 4.6250
# {'train_contrastive': 4.3171875, 'train_loss': 4.3171875, 'test_contrastive': 4.25, 'test_loss': 4.25}
# [22:15:29 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 1/20 (btbank3_0), Loss: 4.2812
# [22:15:29 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 2/20 (btbank3_0), Loss: 4.2500
# [22:15:29 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 3/20 (btbank3_0), Loss: 4.2500
# [22:15:30 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 4/20 (btbank3_0), Loss: 4.2500
# [22:15:30 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 5/20 (btbank3_0), Loss: 4.1875
# [22:15:30 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 6/20 (btbank3_0), Loss: 4.2812
# [22:15:30 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 7/20 (btbank3_0), Loss: 4.2500
# [22:15:30 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 8/20 (btbank3_0), Loss: 4.2812
# [22:15:31 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 9/20 (btbank3_0), Loss: 4.2500
# [22:15:31 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 10/20 (btbank3_0), Loss: 4.2188
# [22:15:31 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 11/20 (btbank3_0), Loss: 4.1875
# [22:15:31 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 12/20 (btbank3_0), Loss: 4.2500
# [22:15:31 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 13/20 (btbank3_0), Loss: 4.2188
# [22:15:32 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 14/20 (btbank3_0), Loss: 4.2500
# [22:15:32 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 15/20 (btbank3_0), Loss: 4.2188
# [22:15:32 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 16/20 (btbank3_0), Loss: 4.1875
# [22:15:32 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 17/20 (btbank3_0), Loss: 4.1250
# [22:15:33 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 18/20 (btbank3_0), Loss: 4.1875
# [22:15:33 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 19/20 (btbank3_0), Loss: 4.1562
# [22:15:33 gpu 14.4G ram 10.9G] (0) Epoch 6/100, Batch 20/20 (btbank3_0), Loss: 4.1250
# [22:15:33 gpu 14.4G ram 10.9G] (0) Estimated time remaining: 0d, 00:07:10
# {'train_contrastive': 4.2203125, 'train_loss': 4.2203125, 'test_contrastive': 4.1875, 'test_loss': 4.1875}
# [22:15:34 gpu 14.4G ram 10.9G] (0) Epoch 7/100, Batch 1/20 (btbank3_0), Loss: 4.1875
# [22:15:34 gpu 14.4G ram 10.9G] (0) Epoch 7/100, Batch 2/20 (btbank3_0), Loss: 4.1562
# [22:15:50 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 14/20 (btbank3_0), Loss: 3.9375
# [22:15:50 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 15/20 (btbank3_0), Loss: 3.9688
# [22:15:50 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 16/20 (btbank3_0), Loss: 3.9688
# [22:15:51 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 17/20 (btbank3_0), Loss: 3.9375
# [22:15:51 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 18/20 (btbank3_0), Loss: 4.0312
# [22:15:51 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 19/20 (btbank3_0), Loss: 3.9531
# [22:15:51 gpu 14.4G ram 10.9G] (0) Epoch 10/100, Batch 20/20 (btbank3_0), Loss: 4.0312
# [22:15:51 gpu 14.4G ram 10.9G] (1)     evaluating on all metrics
# [22:16:10 gpu 14.4G ram 10.9G] (1)     done evaluating on all metrics
# [22:16:10 gpu 14.4G ram 10.9G] (0) Estimated time remaining: 0d, 00:34:46
# {'train_contrastive': 3.97734375, 'train_loss': 3.97734375, 'test_contrastive': 3.96875, 'test_loss': 3.96875, 'eval_auroc/btbank3_0_speech': 0.8807788209551434, 'eval_acc/btbank3_0_speech': 0.7868852459016393, 'eval_auroc/average_speech': 0.8807788209551434, 'eval_acc/average_speech': 0.7868852459016393, 'eval_auroc/btbank3_0_volume': 0.7268711106601732, 'eval_acc/btbank3_0_volume': 0.6449814126394052, 'eval_auroc/average_volume': 0.7268711106601732, 'eval_acc/average_volume': 0.6449814126394052, 'eval_auroc/btbank3_0_gpt2_surprisal': 0.5243301167859455, 'eval_acc/btbank3_0_gpt2_surprisal': 0.516728624535316, 'eval_auroc/average_gpt2_surprisal': 0.5243301167859455, 'eval_acc/average_gpt2_surprisal': 0.516728624535316, 'eval_auroc/btbank3_0_word_part_speech': 0.5190323071718604, 'eval_acc/btbank3_0_word_part_speech': 0.26772908366533865, 'eval_auroc/average_word_part_speech': 0.5190323071718604, 'eval_acc/average_word_part_speech': 0.26772908366533865}
# [22:16:10 gpu 14.4G ram 11.0G] (0) Epoch 11/100, Batch 1/20 (btbank3_0), Loss: 4.0000
# [22:16:11 gpu 14.4G ram 10.9G] (0) Epoch 11/100, Batch 2/20 (btbank3_0), Loss: 3.9688
# [22:16:11 gpu 14.4G ram 10.9G] (0) Epoch 11/100, Batch 3/20 (btbank3_0), Loss: 3.9062
# [22:16:11 gpu 14.4G ram 10.9G] (0) Epoch 11/100, Batch 4/20 (btbank3_0), Loss: 3.9375
# [22:16:11 gpu 14.4G ram 10.9G] (0) Epoch 11/100, Batch 5/20 (btbank3_0), Loss: 4.0000
# [22:16:12 gpu 14.4G ram 10.9G] (0) Epoch 11/100, Batch 6/20 (btbank3_0), Loss: 3.8750
# [22:16:12 gpu 14.4G ram 10.9G] (0) Epoch 11/100, Batch 7/20 (btbank3_0), Loss: 3.9688
# [22:16:22 gpu 14.4G ram 10.9G] (0) Epoch 13/100, Batch 15/20 (btbank3_0), Loss: 3.8125
# [22:16:23 gpu 14.4G ram 10.9G] (0) Epoch 13/100, Batch 16/20 (btbank3_0), Loss: 3.8125
# [22:16:23 gpu 14.4G ram 10.9G] (0) Epoch 13/100, Batch 17/20 (btbank3_0), Loss: 3.7812
# [22:16:23 gpu 14.4G ram 10.9G] (0) Epoch 13/100, Batch 18/20 (btbank3_0), Loss: 3.7344
# [22:16:23 gpu 14.4G ram 10.9G] (0) Epoch 13/100, Batch 19/20 (btbank3_0), Loss: 3.8125
# [22:16:23 gpu 14.4G ram 10.9G] (0) Epoch 13/100, Batch 20/20 (btbank3_0), Loss: 3.8906
# [22:16:24 gpu 14.4G ram 10.9G] (0) Estimated time remaining: 0d, 00:06:31
# {'train_contrastive': 3.81171875, 'train_loss': 3.81171875, 'test_contrastive': 3.921875, 'test_loss': 3.921875}
# [22:16:24 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 1/20 (btbank3_0), Loss: 3.8750
# [22:16:24 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 2/20 (btbank3_0), Loss: 3.7969
# [22:16:24 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 3/20 (btbank3_0), Loss: 3.8281
# [22:16:25 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 4/20 (btbank3_0), Loss: 3.7500
# [22:16:25 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 5/20 (btbank3_0), Loss: 3.7812
# [22:16:25 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 6/20 (btbank3_0), Loss: 3.7344
# [22:16:25 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 7/20 (btbank3_0), Loss: 3.7656
# [22:16:25 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 8/20 (btbank3_0), Loss: 3.7969
# [22:16:26 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 9/20 (btbank3_0), Loss: 3.7656
# [22:16:26 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 10/20 (btbank3_0), Loss: 3.8125
# [22:16:26 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 11/20 (btbank3_0), Loss: 3.7500
# [22:16:26 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 12/20 (btbank3_0), Loss: 3.7188
# [22:16:27 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 13/20 (btbank3_0), Loss: 3.8125
# [22:16:27 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 14/20 (btbank3_0), Loss: 3.6875
# [22:16:27 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 15/20 (btbank3_0), Loss: 3.7188
# [22:16:27 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 16/20 (btbank3_0), Loss: 3.7812
# [22:16:27 gpu 14.4G ram 10.9G] (0) Epoch 14/100, Batch 17/20 (btbank3_0), Loss: 3.7656
# {'train_contrastive': 3.68671875, 'train_loss': 3.68671875, 'test_contrastive': 3.75, 'test_loss': 3.75}
# [22:16:33 gpu 14.4G ram 11.0G] (0) Epoch 16/100, Batch 1/20 (btbank3_0), Loss: 3.5312
# [22:16:33 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 2/20 (btbank3_0), Loss: 3.6250
# [22:16:33 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 3/20 (btbank3_0), Loss: 3.6250
# [22:16:34 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 4/20 (btbank3_0), Loss: 3.7500
# [22:16:34 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 5/20 (btbank3_0), Loss: 3.7188
# [22:16:34 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 6/20 (btbank3_0), Loss: 3.6562
# [22:16:34 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 7/20 (btbank3_0), Loss: 3.7188
# [22:16:34 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 8/20 (btbank3_0), Loss: 3.7500
# [22:16:35 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 9/20 (btbank3_0), Loss: 3.5938
# [22:16:35 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 10/20 (btbank3_0), Loss: 3.6562
# [22:16:35 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 11/20 (btbank3_0), Loss: 3.7031
# [22:16:35 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 12/20 (btbank3_0), Loss: 3.6875
# [22:16:35 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 13/20 (btbank3_0), Loss: 3.6562
# [22:16:36 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 14/20 (btbank3_0), Loss: 3.6562
# [22:16:36 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 15/20 (btbank3_0), Loss: 3.6406
# [22:16:36 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 16/20 (btbank3_0), Loss: 3.6875
# [22:16:36 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 17/20 (btbank3_0), Loss: 3.7500
# [22:16:36 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 18/20 (btbank3_0), Loss: 3.5938
# [22:16:37 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 19/20 (btbank3_0), Loss: 3.5938
# [22:16:37 gpu 14.4G ram 10.9G] (0) Epoch 16/100, Batch 20/20 (btbank3_0), Loss: 3.5000
# [22:16:37 gpu 14.4G ram 10.9G] (0) Estimated time remaining: 0d, 00:06:14
# {'train_contrastive': 3.6546875, 'train_loss': 3.6546875, 'test_contrastive': 3.734375, 'test_loss': 3.734375}
# [22:16:37 gpu 14.4G ram 11.0G] (0) Epoch 17/100, Batch 1/20 (btbank3_0), Loss: 3.6250
# [22:16:38 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 2/20 (btbank3_0), Loss: 3.6094
# [22:16:38 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 3/20 (btbank3_0), Loss: 3.6562
# [22:16:38 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 4/20 (btbank3_0), Loss: 3.5938
# [22:16:38 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 5/20 (btbank3_0), Loss: 3.6250
# [22:16:38 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 6/20 (btbank3_0), Loss: 3.5938
# [22:16:39 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 7/20 (btbank3_0), Loss: 3.5781
# [22:16:39 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 8/20 (btbank3_0), Loss: 3.5781
# [22:16:39 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 9/20 (btbank3_0), Loss: 3.6250
# [22:16:39 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 10/20 (btbank3_0), Loss: 3.5781
# [22:16:40 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 11/20 (btbank3_0), Loss: 3.5938
# [22:16:40 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 12/20 (btbank3_0), Loss: 3.5625
# [22:16:40 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 13/20 (btbank3_0), Loss: 3.6562
# [22:16:40 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 14/20 (btbank3_0), Loss: 3.5625
# [22:16:40 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 15/20 (btbank3_0), Loss: 3.5625
# [22:16:41 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 16/20 (btbank3_0), Loss: 3.5469
# [22:16:41 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 17/20 (btbank3_0), Loss: 3.5156
# [22:16:41 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 18/20 (btbank3_0), Loss: 3.5156
# [22:16:41 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 19/20 (btbank3_0), Loss: 3.5938
# [22:16:41 gpu 14.4G ram 10.9G] (0) Epoch 17/100, Batch 20/20 (btbank3_0), Loss: 3.7500
# [22:16:42 gpu 14.4G ram 10.9G] (0) Estimated time remaining: 0d, 00:06:12
# {'train_contrastive': 3.59609375, 'train_loss': 3.59609375, 'test_contrastive': 3.71875, 'test_loss': 3.71875}
# [22:16:42 gpu 14.4G ram 11.0G] (0) Epoch 18/100, Batch 1/20 (btbank3_0), Loss: 3.5625
# [22:16:42 gpu 14.4G ram 10.9G] (0) Epoch 18/100, Batch 2/20 (btbank3_0), Loss: 3.5156
# [22:16:42 gpu 14.4G ram 10.9G] (0) Epoch 18/100, Batch 3/20 (btbank3_0), Loss: 3.5000
# [22:16:43 gpu 14.4G ram 10.9G] (0) Epoch 18/100, Batch 4/20 (btbank3_0), Loss: 3.4531
# [22:16:43 gpu 14.4G ram 10.9G] (0) Epoch 18/100, Batch 5/20 (btbank3_0), Loss: 3.5312
# [22:16:43 gpu 14.4G ram 10.9G] (0) Epoch 18/100, Batch 6/20 (btbank3_0), Loss: 3.5625
# [22:16:48 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 10/20 (btbank3_0), Loss: 3.5625
# [22:16:49 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 11/20 (btbank3_0), Loss: 3.3750
# [22:16:49 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 12/20 (btbank3_0), Loss: 3.6562
# [22:16:49 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 13/20 (btbank3_0), Loss: 3.5156
# [22:16:49 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 14/20 (btbank3_0), Loss: 3.4531
# [22:16:49 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 15/20 (btbank3_0), Loss: 3.3750
# [22:16:50 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 16/20 (btbank3_0), Loss: 3.5938
# [22:16:50 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 17/20 (btbank3_0), Loss: 3.3750
# [22:16:50 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 18/20 (btbank3_0), Loss: 3.5625
# [22:16:50 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 19/20 (btbank3_0), Loss: 3.3750
# [22:16:50 gpu 14.4G ram 10.9G] (0) Epoch 19/100, Batch 20/20 (btbank3_0), Loss: 3.3906
# [22:16:51 gpu 14.4G ram 10.9G] (0) Estimated time remaining: 0d, 00:06:11
# {'train_contrastive': 3.46640625, 'train_loss': 3.46640625, 'test_contrastive': 3.625, 'test_loss': 3.625}
# [22:16:51 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 1/20 (btbank3_0), Loss: 3.3750
# [22:16:51 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 2/20 (btbank3_0), Loss: 3.5000
# [22:16:52 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 3/20 (btbank3_0), Loss: 3.3750
# [22:16:52 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 4/20 (btbank3_0), Loss: 3.3438
# [22:16:52 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 5/20 (btbank3_0), Loss: 3.3125
# [22:16:52 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 6/20 (btbank3_0), Loss: 3.2812
# [22:16:52 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 7/20 (btbank3_0), Loss: 3.3438
# [22:16:53 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 8/20 (btbank3_0), Loss: 3.2969
# [22:16:53 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 9/20 (btbank3_0), Loss: 3.3438
# [22:16:53 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 10/20 (btbank3_0), Loss: 3.2812
# [22:16:53 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 11/20 (btbank3_0), Loss: 3.5000
# [22:16:53 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 12/20 (btbank3_0), Loss: 3.5625
# [22:16:54 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 13/20 (btbank3_0), Loss: 3.4375
# [22:16:54 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 14/20 (btbank3_0), Loss: 3.4219
# [22:16:54 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 15/20 (btbank3_0), Loss: 3.4062
# [22:16:54 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 16/20 (btbank3_0), Loss: 3.3125
# [22:16:54 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 17/20 (btbank3_0), Loss: 3.4062
# [22:16:55 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 18/20 (btbank3_0), Loss: 3.3438
# [22:16:55 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 19/20 (btbank3_0), Loss: 3.3438
# [22:16:55 gpu 14.4G ram 10.9G] (0) Epoch 20/100, Batch 20/20 (btbank3_0), Loss: 3.4375
# [22:16:55 gpu 14.4G ram 10.9G] (1)     evaluating on all metrics
# [22:17:14 gpu 14.4G ram 10.8G] (1)     done evaluating on all metrics
# [22:17:14 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:30:56
# {'train_contrastive': 3.38125, 'train_loss': 3.38125, 'test_contrastive': 3.65625, 'test_loss': 3.65625, 'eval_auroc/btbank3_0_speech': 0.9442663409917817, 'eval_acc/btbank3_0_speech': 0.8789407313997478, 'eval_auroc/average_speech': 0.9442663409917817, 'eval_acc/average_speech': 0.8789407313997478, 'eval_auroc/btbank3_0_volume': 0.7867458062770563, 'eval_acc/btbank3_0_volume': 0.6756505576208178, 'eval_auroc/average_volume': 0.7867458062770563, 'eval_acc/average_volume': 0.6756505576208178, 'eval_auroc/btbank3_0_gpt2_surprisal': 0.5210200852436992, 'eval_acc/btbank3_0_gpt2_surprisal': 0.5102230483271375, 'eval_auroc/average_gpt2_surprisal': 0.5210200852436992, 'eval_acc/average_gpt2_surprisal': 0.5102230483271375, 'eval_auroc/btbank3_0_word_part_speech': 0.5080500733550276, 'eval_acc/btbank3_0_word_part_speech': 0.2557768924302789, 'eval_auroc/average_word_part_speech': 0.5080500733550276, 'eval_acc/average_word_part_speech': 0.2557768924302789}
# [22:17:14 gpu 14.4G ram 10.9G] (0) Epoch 21/100, Batch 1/20 (btbank3_0), Loss: 3.4062
# [22:17:14 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 2/20 (btbank3_0), Loss: 3.4062
# [22:17:15 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 3/20 (btbank3_0), Loss: 3.3125
# [22:17:15 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 4/20 (btbank3_0), Loss: 3.3125
# [22:17:15 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 5/20 (btbank3_0), Loss: 3.3438
# [22:17:15 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 6/20 (btbank3_0), Loss: 3.3594
# [22:17:15 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 7/20 (btbank3_0), Loss: 3.3125
# [22:17:16 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 8/20 (btbank3_0), Loss: 3.3438
# [22:17:16 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 9/20 (btbank3_0), Loss: 3.3750
# [22:17:16 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 10/20 (btbank3_0), Loss: 3.3594
# [22:17:16 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 11/20 (btbank3_0), Loss: 3.2812
# [22:17:16 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 12/20 (btbank3_0), Loss: 3.3125
# [22:17:17 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 13/20 (btbank3_0), Loss: 3.3281
# [22:17:17 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 14/20 (btbank3_0), Loss: 3.3125
# [22:17:17 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 15/20 (btbank3_0), Loss: 3.2500
# [22:17:17 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 16/20 (btbank3_0), Loss: 3.3594
# [22:17:18 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 17/20 (btbank3_0), Loss: 3.3125
# [22:17:18 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 18/20 (btbank3_0), Loss: 3.1562
# [22:17:18 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 19/20 (btbank3_0), Loss: 3.3125
# [22:17:18 gpu 14.4G ram 10.8G] (0) Epoch 21/100, Batch 20/20 (btbank3_0), Loss: 3.3281
# [22:17:18 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:05:54
# {'train_contrastive': 3.32421875, 'train_loss': 3.32421875, 'test_contrastive': 3.640625, 'test_loss': 3.640625}
# [22:17:19 gpu 14.4G ram 11.0G] (0) Epoch 22/100, Batch 1/20 (btbank3_0), Loss: 3.3438
# [22:17:19 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 2/20 (btbank3_0), Loss: 3.2500
# [22:17:19 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 3/20 (btbank3_0), Loss: 3.2188
# [22:17:19 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 4/20 (btbank3_0), Loss: 3.3125
# [22:17:20 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 5/20 (btbank3_0), Loss: 3.3750
# [22:17:20 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 6/20 (btbank3_0), Loss: 3.3438
# [22:17:20 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 7/20 (btbank3_0), Loss: 3.2500
# [22:17:20 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 8/20 (btbank3_0), Loss: 3.3750
# [22:17:20 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 9/20 (btbank3_0), Loss: 3.2812
# [22:17:21 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 10/20 (btbank3_0), Loss: 3.2812
# [22:17:21 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 11/20 (btbank3_0), Loss: 3.1562
# [22:17:21 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 12/20 (btbank3_0), Loss: 3.2812
# [22:17:21 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 13/20 (btbank3_0), Loss: 3.1719
# [22:17:21 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 14/20 (btbank3_0), Loss: 3.3125
# [22:17:22 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 15/20 (btbank3_0), Loss: 3.2031
# [22:17:22 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 16/20 (btbank3_0), Loss: 3.3438
# [22:17:22 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 17/20 (btbank3_0), Loss: 3.2188
# [22:17:22 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 18/20 (btbank3_0), Loss: 3.1250
# [22:17:22 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 19/20 (btbank3_0), Loss: 3.2031
# [22:17:23 gpu 14.4G ram 10.8G] (0) Epoch 22/100, Batch 20/20 (btbank3_0), Loss: 3.2031
# [22:17:23 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:05:53
# {'train_contrastive': 3.2625, 'train_loss': 3.2625, 'test_contrastive': 3.578125, 'test_loss': 3.578125}
# [22:17:23 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 1/20 (btbank3_0), Loss: 3.1875
# [22:17:24 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 2/20 (btbank3_0), Loss: 3.1562
# [22:17:24 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 3/20 (btbank3_0), Loss: 3.3125
# [22:17:24 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 4/20 (btbank3_0), Loss: 3.1719
# [22:17:24 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 5/20 (btbank3_0), Loss: 3.2344
# [22:17:24 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 6/20 (btbank3_0), Loss: 3.2031
# [22:17:25 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 7/20 (btbank3_0), Loss: 3.1875
# [22:17:25 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 8/20 (btbank3_0), Loss: 3.2656
# [22:17:25 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 9/20 (btbank3_0), Loss: 3.1250
# [22:17:25 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 10/20 (btbank3_0), Loss: 3.0781
# [22:17:25 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 11/20 (btbank3_0), Loss: 3.1562
# [22:17:26 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 12/20 (btbank3_0), Loss: 3.0312
# [22:17:26 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 13/20 (btbank3_0), Loss: 3.2812
# [22:17:26 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 14/20 (btbank3_0), Loss: 3.1875
# [22:17:26 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 15/20 (btbank3_0), Loss: 3.2188
# [22:17:26 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 16/20 (btbank3_0), Loss: 3.1094
# [22:17:27 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 17/20 (btbank3_0), Loss: 3.1562
# [22:17:27 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 18/20 (btbank3_0), Loss: 3.3125
# [22:17:27 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 19/20 (btbank3_0), Loss: 3.1406
# [22:17:27 gpu 14.4G ram 10.8G] (0) Epoch 23/100, Batch 20/20 (btbank3_0), Loss: 3.1250
# [22:17:27 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:05:52
# {'train_contrastive': 3.18203125, 'train_loss': 3.18203125, 'test_contrastive': 3.640625, 'test_loss': 3.640625}
# [22:17:28 gpu 14.4G ram 11.0G] (0) Epoch 24/100, Batch 1/20 (btbank3_0), Loss: 3.1562
# [22:17:28 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 2/20 (btbank3_0), Loss: 3.0625
# [22:17:28 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 3/20 (btbank3_0), Loss: 3.1562
# [22:17:28 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 4/20 (btbank3_0), Loss: 3.1562
# [22:17:29 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 5/20 (btbank3_0), Loss: 3.1094
# [22:17:29 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 6/20 (btbank3_0), Loss: 3.1406
# [22:17:29 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 7/20 (btbank3_0), Loss: 3.1562
# [22:17:29 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 8/20 (btbank3_0), Loss: 3.2656
# [22:17:29 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 9/20 (btbank3_0), Loss: 3.0312
# [22:17:30 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 10/20 (btbank3_0), Loss: 3.1875
# [22:17:30 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 11/20 (btbank3_0), Loss: 3.1562
# [22:17:30 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 12/20 (btbank3_0), Loss: 3.1562
# [22:17:30 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 13/20 (btbank3_0), Loss: 3.0781
# [22:17:31 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 14/20 (btbank3_0), Loss: 3.0156
# [22:17:31 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 15/20 (btbank3_0), Loss: 3.0000
# [22:17:31 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 16/20 (btbank3_0), Loss: 3.0938
# [22:17:31 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 17/20 (btbank3_0), Loss: 3.0625
# [22:17:31 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 18/20 (btbank3_0), Loss: 3.1250
# [22:17:32 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 19/20 (btbank3_0), Loss: 3.2031
# [22:17:32 gpu 14.4G ram 10.8G] (0) Epoch 24/100, Batch 20/20 (btbank3_0), Loss: 2.9688
# [22:17:32 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:05:42
# {'train_contrastive': 3.1140625, 'train_loss': 3.1140625, 'test_contrastive': 3.5, 'test_loss': 3.5}
# [22:17:32 gpu 14.4G ram 10.8G] (0) Epoch 25/100, Batch 1/20 (btbank3_0), Loss: 3.0312
# [22:17:33 gpu 14.4G ram 10.8G] (0) Epoch 25/100, Batch 2/20 (btbank3_0), Loss: 2.9062
# [22:17:33 gpu 14.4G ram 10.8G] (0) Epoch 25/100, Batch 3/20 (btbank3_0), Loss: 3.0938
# ...
# [22:24:52 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 6/20 (btbank3_0), Loss: 0.1914
# [22:24:53 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 7/20 (btbank3_0), Loss: 0.1660
# [22:24:53 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 8/20 (btbank3_0), Loss: 0.1309
# [22:24:53 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 9/20 (btbank3_0), Loss: 0.1699
# [22:24:53 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 10/20 (btbank3_0), Loss: 0.1436
# [22:24:54 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 11/20 (btbank3_0), Loss: 0.1816
# [22:24:54 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 12/20 (btbank3_0), Loss: 0.1660
# [22:24:54 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 13/20 (btbank3_0), Loss: 0.2227
# [22:24:54 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 14/20 (btbank3_0), Loss: 0.1680
# [22:24:54 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 15/20 (btbank3_0), Loss: 0.1924
# [22:24:55 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 16/20 (btbank3_0), Loss: 0.1216
# [22:24:55 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 17/20 (btbank3_0), Loss: 0.1797
# [22:24:55 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 18/20 (btbank3_0), Loss: 0.1270
# [22:24:55 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 19/20 (btbank3_0), Loss: 0.1240
# [22:24:55 gpu 14.4G ram 10.8G] (0) Epoch 93/100, Batch 20/20 (btbank3_0), Loss: 0.1660
# [22:24:56 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:00:31
# {'train_contrastive': 0.1619140625, 'train_loss': 0.1619140625, 'test_contrastive': 5.3125, 'test_loss': 5.3125}
# [22:24:56 gpu 14.4G ram 10.9G] (0) Epoch 94/100, Batch 1/20 (btbank3_0), Loss: 0.1816
# [22:25:01 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 5/20 (btbank3_0), Loss: 0.1396
# [22:25:02 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 6/20 (btbank3_0), Loss: 0.1836
# [22:25:02 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 7/20 (btbank3_0), Loss: 0.1211
# [22:25:02 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 8/20 (btbank3_0), Loss: 0.0957
# [22:25:02 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 9/20 (btbank3_0), Loss: 0.2129
# [22:25:02 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 10/20 (btbank3_0), Loss: 0.1914
# [22:25:03 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 11/20 (btbank3_0), Loss: 0.2227
# [22:25:03 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 12/20 (btbank3_0), Loss: 0.1973
# [22:25:03 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 13/20 (btbank3_0), Loss: 0.1104
# [22:25:03 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 14/20 (btbank3_0), Loss: 0.1758
# [22:25:03 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 15/20 (btbank3_0), Loss: 0.1865
# [22:25:04 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 16/20 (btbank3_0), Loss: 0.1465
# [22:25:04 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 17/20 (btbank3_0), Loss: 0.1582
# [22:25:04 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 18/20 (btbank3_0), Loss: 0.1914
# [22:25:04 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 19/20 (btbank3_0), Loss: 0.2168
# [22:25:04 gpu 14.4G ram 10.8G] (0) Epoch 95/100, Batch 20/20 (btbank3_0), Loss: 0.1748
# [22:25:05 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:00:22
# {'train_contrastive': 0.158740234375, 'train_loss': 0.158740234375, 'test_contrastive': 5.25, 'test_loss': 5.25}
# [22:25:05 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 1/20 (btbank3_0), Loss: 0.1719
# [22:25:05 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 2/20 (btbank3_0), Loss: 0.0996
# [22:25:06 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 3/20 (btbank3_0), Loss: 0.1445
# [22:25:06 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 4/20 (btbank3_0), Loss: 0.1543
# [22:25:06 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 5/20 (btbank3_0), Loss: 0.1040
# [22:25:06 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 6/20 (btbank3_0), Loss: 0.1191
# [22:25:06 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 7/20 (btbank3_0), Loss: 0.1699
# [22:25:07 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 8/20 (btbank3_0), Loss: 0.1133
# [22:25:07 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 9/20 (btbank3_0), Loss: 0.1465
# [22:25:07 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 10/20 (btbank3_0), Loss: 0.1230
# [22:25:07 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 11/20 (btbank3_0), Loss: 0.1562
# [22:25:07 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 12/20 (btbank3_0), Loss: 0.1836
# [22:25:08 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 13/20 (btbank3_0), Loss: 0.1475
# [22:25:08 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 14/20 (btbank3_0), Loss: 0.1201
# [22:25:08 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 15/20 (btbank3_0), Loss: 0.1016
# [22:25:08 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 16/20 (btbank3_0), Loss: 0.1621
# [22:25:08 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 17/20 (btbank3_0), Loss: 0.1699
# [22:25:09 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 18/20 (btbank3_0), Loss: 0.2148
# [22:25:09 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 19/20 (btbank3_0), Loss: 0.1406
# [22:25:09 gpu 14.4G ram 10.8G] (0) Epoch 96/100, Batch 20/20 (btbank3_0), Loss: 0.1426
# [22:25:09 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:00:18
# {'train_contrastive': 0.1442626953125, 'train_loss': 0.1442626953125, 'test_contrastive': 5.3125, 'test_loss': 5.3125}
# [22:25:10 gpu 14.4G ram 10.9G] (0) Epoch 97/100, Batch 1/20 (btbank3_0), Loss: 0.1270
# [22:25:10 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 2/20 (btbank3_0), Loss: 0.1592
# [22:25:10 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 3/20 (btbank3_0), Loss: 0.1807
# [22:25:10 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 4/20 (btbank3_0), Loss: 0.1318
# [22:25:10 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 5/20 (btbank3_0), Loss: 0.1201
# [22:25:11 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 6/20 (btbank3_0), Loss: 0.0967
# [22:25:11 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 7/20 (btbank3_0), Loss: 0.1113
# [22:25:11 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 8/20 (btbank3_0), Loss: 0.1069
# [22:25:11 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 9/20 (btbank3_0), Loss: 0.2148
# [22:25:11 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 10/20 (btbank3_0), Loss: 0.1758
# [22:25:12 gpu 14.4G ram 10.8G] (0) Epoch 97/100, Batch 11/20 (btbank3_0), Loss: 0.1455
# [22:25:17 gpu 14.4G ram 10.8G] (0) Epoch 98/100, Batch 15/20 (btbank3_0), Loss: 0.1436
# [22:25:17 gpu 14.4G ram 10.8G] (0) Epoch 98/100, Batch 16/20 (btbank3_0), Loss: 0.1138
# [22:25:17 gpu 14.4G ram 10.8G] (0) Epoch 98/100, Batch 17/20 (btbank3_0), Loss: 0.1367
# [22:25:18 gpu 14.4G ram 10.8G] (0) Epoch 98/100, Batch 18/20 (btbank3_0), Loss: 0.1406
# [22:25:18 gpu 14.4G ram 10.8G] (0) Epoch 98/100, Batch 19/20 (btbank3_0), Loss: 0.1367
# [22:25:18 gpu 14.4G ram 10.8G] (0) Epoch 98/100, Batch 20/20 (btbank3_0), Loss: 0.1143
# [22:25:18 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:00:09
# {'train_contrastive': 0.1408935546875, 'train_loss': 0.1408935546875, 'test_contrastive': 5.25, 'test_loss': 5.25}
# [22:25:19 gpu 14.4G ram 10.9G] (0) Epoch 99/100, Batch 1/20 (btbank3_0), Loss: 0.1270
# [22:25:19 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 2/20 (btbank3_0), Loss: 0.2168
# [22:25:19 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 3/20 (btbank3_0), Loss: 0.1084
# [22:25:19 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 4/20 (btbank3_0), Loss: 0.1504
# [22:25:19 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 5/20 (btbank3_0), Loss: 0.1338
# [22:25:20 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 6/20 (btbank3_0), Loss: 0.1299
# [22:25:20 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 7/20 (btbank3_0), Loss: 0.1348
# [22:25:20 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 8/20 (btbank3_0), Loss: 0.1758
# [22:25:20 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 9/20 (btbank3_0), Loss: 0.1152
# [22:25:21 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 10/20 (btbank3_0), Loss: 0.1250
# [22:25:21 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 11/20 (btbank3_0), Loss: 0.1377
# [22:25:21 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 12/20 (btbank3_0), Loss: 0.1826
# [22:25:21 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 13/20 (btbank3_0), Loss: 0.1416
# [22:25:21 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 14/20 (btbank3_0), Loss: 0.1738
# [22:25:22 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 15/20 (btbank3_0), Loss: 0.1021
# [22:25:22 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 16/20 (btbank3_0), Loss: 0.1289
# [22:25:22 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 17/20 (btbank3_0), Loss: 0.1299
# [22:25:22 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 18/20 (btbank3_0), Loss: 0.1797
# [22:25:22 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 19/20 (btbank3_0), Loss: 0.2520
# [22:25:23 gpu 14.4G ram 10.8G] (0) Epoch 99/100, Batch 20/20 (btbank3_0), Loss: 0.0996
# [22:25:23 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:00:04
# {'train_contrastive': 0.1472412109375, 'train_loss': 0.1472412109375, 'test_contrastive': 5.28125, 'test_loss': 5.28125}
# [22:25:23 gpu 14.4G ram 10.9G] (0) Epoch 100/100, Batch 1/20 (btbank3_0), Loss: 0.1025
# [22:25:23 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 2/20 (btbank3_0), Loss: 0.1387
# [22:25:24 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 3/20 (btbank3_0), Loss: 0.1123
# [22:25:24 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 4/20 (btbank3_0), Loss: 0.1621
# [22:25:24 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 5/20 (btbank3_0), Loss: 0.1230
# [22:25:24 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 6/20 (btbank3_0), Loss: 0.1514
# [22:25:24 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 7/20 (btbank3_0), Loss: 0.1187
# [22:25:25 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 8/20 (btbank3_0), Loss: 0.0996
# [22:25:25 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 9/20 (btbank3_0), Loss: 0.0889
# [22:25:25 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 10/20 (btbank3_0), Loss: 0.1016
# [22:25:25 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 11/20 (btbank3_0), Loss: 0.1348
# [22:25:25 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 12/20 (btbank3_0), Loss: 0.1187
# [22:25:26 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 13/20 (btbank3_0), Loss: 0.1797
# [22:25:26 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 14/20 (btbank3_0), Loss: 0.2461
# [22:25:26 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 15/20 (btbank3_0), Loss: 0.1729
# [22:25:26 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 16/20 (btbank3_0), Loss: 0.1699
# [22:25:26 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 17/20 (btbank3_0), Loss: 0.1162
# [22:25:27 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 18/20 (btbank3_0), Loss: 0.1289
# [22:25:27 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 19/20 (btbank3_0), Loss: 0.1621
# [22:25:27 gpu 14.4G ram 10.8G] (0) Epoch 100/100, Batch 20/20 (btbank3_0), Loss: 0.1152
# [22:25:27 gpu 14.4G ram 10.8G] (1)     evaluating on all metrics
# [22:25:46 gpu 14.4G ram 10.8G] (1)     done evaluating on all metrics
# [22:25:46 gpu 14.4G ram 10.8G] (0) Estimated time remaining: 0d, 00:00:00
# {'train_contrastive': 0.137158203125, 'train_loss': 0.137158203125, 'test_contrastive': 5.1875, 'test_loss': 5.1875, 'eval_auroc/btbank3_0_speech': 0.998110831234257, 'eval_acc/btbank3_0_speech': 0.9684741488020177, 'eval_auroc/average_speech': 0.998110831234257, 'eval_acc/average_speech': 0.9684741488020177, 'eval_auroc/btbank3_0_volume': 0.8158820346320346, 'eval_acc/btbank3_0_volume': 0.7202602230483272, 'eval_auroc/average_volume': 0.8158820346320346, 'eval_acc/average_volume': 0.7202602230483272, 'eval_auroc/btbank3_0_gpt2_surprisal': 0.5602418815936625, 'eval_acc/btbank3_0_gpt2_surprisal': 0.5371747211895911, 'eval_auroc/average_gpt2_surprisal': 0.5602418815936625, 'eval_acc/average_gpt2_surprisal': 0.5371747211895911, 'eval_auroc/btbank3_0_word_part_speech': 0.5192625172949596, 'eval_acc/btbank3_0_word_part_speech': 0.2653386454183267, 'eval_auroc/average_word_part_speech': 0.5192625172949596, 'eval_acc/average_word_part_speech': 0.2653386454183267}

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path = 'analyses/font_arial.ttf'
fm.fontManager.addfont(font_path)
plt.rcParams['font.family'] = 'Arial'
plt.rcParams.update({'font.size': 12})

# Create figure with 5 subplots - one for loss, four for metrics
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(12, 3))
fig.tight_layout(pad=3.0)

# Extract epochs and corresponding values
epochs = [stat['epoch'] for stat in training_statistics_store if 'train_loss' in stat]
train_loss = [stat['train_loss'] for stat in training_statistics_store if 'train_loss' in stat]
test_loss = [stat['test_loss'] for stat in training_statistics_store if 'test_loss' in stat]

# Plot losses
ax1.plot(epochs, train_loss, label='Train', linewidth=2)
ax1.plot(epochs, test_loss, label='Test', linewidth=2)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Loss')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xticks([10, 100])
ax1.legend()
ax1.grid(True)

# Plot metrics
metrics = ['speech', 'volume', 'gpt2_surprisal', 'word_part_speech']
axes = [ax2, ax3, ax4, ax5]

for ax, metric in zip(axes, metrics):
    auroc_values = [stat[f'eval_auroc/average_{metric}'] for stat in training_statistics_store 
                   if f'eval_auroc/average_{metric}' in stat]
    acc_values = [stat[f'eval_acc/average_{metric}'] for stat in training_statistics_store 
                 if f'eval_acc/average_{metric}' in stat]
    metric_epochs = [stat['epoch'] for stat in training_statistics_store 
                    if f'eval_auroc/average_{metric}' in stat]
    
    ax.plot(metric_epochs, auroc_values, label='AUROC', linewidth=2)
    #ax.plot(metric_epochs, acc_values, label='Accuracy')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Decoding AUROC')
    ax.set_title(f'{metric.replace("_", " ").title()}')
    ax.set_xscale('log')
    ax.set_xticks([10, 100]) #[1, 10, 100]
    ax.set_ylim(0.5, 1.0)
    #ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.savefig(f'analyses/contra_training_exp_{dir_name}.png')
plt.show()
