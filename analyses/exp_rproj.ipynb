# %%
import wandb
import os
import torch
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
from train_utils import update_dir_name, get_default_configs
font_path = 'analyses/font_arial.ttf'
fm.fontManager.addfont(font_path)
plt.rcParams['font.family'] = 'Arial'
plt.rcParams.update({'font.size': 12})

# Get wandb run history
api = wandb.Api()
wandb_path = os.path.join("..", "wandb")

# %%
training_config, model_config, cluster_config = get_default_configs(random_string="X", wandb_project="btbank_tests")

# %%
random_strings = ["CONT_EXPRPR1", "CONT_EXP_CLS2", "CONT_EXP_CLS3"]


learning_rates = sorted([0.00075, 0.0015, 0.003, 0.006, 0.012])
projection_type_options = ["None", "random_batch"]
future_bin_idx = [1]
use_cls_token_options = [1]
spec_values = [1]#, 0]

condition_str = [f"{projection_type}_{lr}" for projection_type in projection_type_options for lr in learning_rates]

# Initialize histories dict
histories = {cs: [] for cs in condition_str}

# Generate all run IDs and collect histories
for cs in condition_str:
    for rs in random_strings:
        training_config['random_string'] = rs
        training_config['learning_rate'] = float(cs.split("_")[-1])
        training_config['future_bin_idx'] = future_bin_idx[0]
        model_config['transformer']['use_cls_token'] = use_cls_token_options[0]
        model_config['electrode_embedding']['spectrogram'] = spec_values[0]
        training_config['projection_type'] = "_".join(cs.split("_")[:-1])#None if cs.split("_")[0] == "None" else "random_batch"

        run_id = update_dir_name(model_config, training_config, cluster_config)
        
        runs = api.runs(f"andrii-mit/{cluster_config['wandb_project']}", filters={"display_name": run_id})
        if len(runs) > 0:
            run = runs[0]
            history = run.history()
            if '_step' not in history.columns:
                print(f"Run {run_id} has no '_step' column")
                continue
            n_epochs = 100
            if history['_step'].max() >= n_epochs:  # Only include if trained for full 100 epochs
                histories[cs].append(history)
            else:
                print(f"Run {run_id} did not train for full {n_epochs} epochs ({history['_step'].max()} epochs)")

for cs in condition_str:
    print(f"condition {cs}: {len(histories[cs])} runs")
# Out:
# Run M_nst8_dm192_nh12_nl5_5_eaM_projRB_eeL_fb1_cls_lr0.006_rCONT_EXP_CLS2 did not train for full 100 epochs (98 epochs)
# condition None_0.00075: 2 runs
# condition None_0.0015: 2 runs
# condition None_0.003: 2 runs
# condition None_0.006: 2 runs
# condition None_0.012: 2 runs
# condition random_batch_0.00075: 2 runs
# condition random_batch_0.0015: 2 runs
# condition random_batch_0.003: 2 runs
# condition random_batch_0.006: 1 runs
# condition random_batch_0.012: 2 runs

# %%
metrics = ['train_loss', 'test_loss', 'eval_auroc/average_speech', 'eval_auroc/average_volume', 'eval_auroc/average_gpt2_surprisal', 'eval_auroc/average_word_part_speech']
metric_names = ['Training Loss', 'Test Loss', 'Decoding Speech AUROC', 'Decoding Volume AUROC', 'Decoding GPT2 Surprisal AUROC', 'Decoding Word Part Speech AUROC']
n_last_measurements = 3

# Initialize results dictionary
results = {cs: {metric: [] for metric in metrics} 
          for cs in condition_str}

# Calculate means for each run
for cs in condition_str:
    for history in histories[cs]:
        for metric in metrics:
            h = np.array(list(history[metric].iloc))
            h = h[~np.isnan(h)]
            results[cs][metric].append(h[-n_last_measurements:].mean())

# Print results
for cs in condition_str:
    print(f"\ncs {cs}:")
    for metric in metrics:
        values = results[cs][metric]
        if values:
            mean = sum(values) / len(values)
            print(f"{metric}: {mean:.4f} (across {len(values)} runs)")
# Out:
# cs None_0.00075:
# train_loss: 2.8608 (across 2 runs)
# test_loss: 2.8958 (across 2 runs)
# eval_auroc/average_speech: 0.6538 (across 2 runs)
# eval_auroc/average_volume: 0.6309 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5060 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.4973 (across 2 runs)
#
# cs None_0.0015:
# train_loss: 0.2886 (across 2 runs)
# test_loss: 0.5114 (across 2 runs)
# eval_auroc/average_speech: 0.8404 (across 2 runs)
# eval_auroc/average_volume: 0.7325 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5199 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5154 (across 2 runs)
#
# cs None_0.003:
# train_loss: 0.0986 (across 2 runs)
# test_loss: 0.3890 (across 2 runs)
# eval_auroc/average_speech: 0.8782 (across 2 runs)
# eval_auroc/average_volume: 0.7396 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5299 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5107 (across 2 runs)
#
# cs None_0.006:
# train_loss: 0.0872 (across 2 runs)
# test_loss: 0.2874 (across 2 runs)
# eval_auroc/average_speech: 0.8578 (across 2 runs)
# eval_auroc/average_volume: 0.7268 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5293 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5054 (across 2 runs)
#
# cs None_0.012:
# train_loss: 0.4173 (across 2 runs)
# test_loss: 0.5726 (across 2 runs)
# eval_auroc/average_speech: 0.8600 (across 2 runs)
# eval_auroc/average_volume: 0.7144 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5296 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5088 (across 2 runs)
#
# cs random_batch_0.00075:
# train_loss: 2.8874 (across 2 runs)
# test_loss: 2.9167 (across 2 runs)
# eval_auroc/average_speech: 0.6350 (across 2 runs)
# eval_auroc/average_volume: 0.6341 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5074 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.4923 (across 2 runs)
#
# cs random_batch_0.0015:
# train_loss: 0.7210 (across 2 runs)
# test_loss: 0.8672 (across 2 runs)
# eval_auroc/average_speech: 0.7752 (across 2 runs)
# eval_auroc/average_volume: 0.7265 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5090 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5007 (across 2 runs)
#
# cs random_batch_0.003:
# train_loss: 0.3563 (across 2 runs)
# test_loss: 0.5898 (across 2 runs)
# eval_auroc/average_speech: 0.8291 (across 2 runs)
# eval_auroc/average_volume: 0.7457 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5199 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5101 (across 2 runs)
#
# cs random_batch_0.006:
# train_loss: 0.3454 (across 1 runs)
# test_loss: 0.5299 (across 1 runs)
# eval_auroc/average_speech: 0.8264 (across 1 runs)
# eval_auroc/average_volume: 0.7261 (across 1 runs)
# eval_auroc/average_gpt2_surprisal: 0.5341 (across 1 runs)
# eval_auroc/average_word_part_speech: 0.5081 (across 1 runs)
#
# cs random_batch_0.012:
# train_loss: 0.7264 (across 2 runs)
# test_loss: 2.0182 (across 2 runs)
# eval_auroc/average_speech: 0.8167 (across 2 runs)
# eval_auroc/average_volume: 0.7210 (across 2 runs)
# eval_auroc/average_gpt2_surprisal: 0.5196 (across 2 runs)
# eval_auroc/average_word_part_speech: 0.5064 (across 2 runs)

# %%
# Set error bar type ('std' for standard deviation or 'sem' for standard error of mean)
error_type = 'sem'

fig, axes = plt.subplots(1, len(metrics), figsize=(3.5*len(metrics), 6))

for i, metric in enumerate(metrics):
    for projection_type_idx, projection_type in enumerate(projection_type_options):
        means = []
        errors = []
        ps = []
        all_values = []
        all_ps = []
        
        # Calculate base x position for this batch size group
        base_x = projection_type_idx * (len(learning_rates) + 1)  # +1 for spacing between groups
        
        # Get data for each learning rate within this batch size
        for lr_idx, lr in enumerate(learning_rates):
            cs = f"{projection_type}_{lr}"  # Reconstruct condition string
            values = results[cs][metric] if cs in results else []
            
            if values:
                means.append(np.mean(values))
                if error_type == 'std':
                    errors.append(np.std(values))
                else:  # sem
                    errors.append(np.std(values) / np.sqrt(len(values)))
                
                x_ind = base_x + lr_idx
                ps.append(x_ind)
                
                # Store individual points
                all_values.extend(values)
                all_ps.extend([x_ind] * len(values))
        
        # Plot individual points with some jitter and transparency
        jitter = 0.1
        axes[i].scatter(
            [p + np.random.uniform(-jitter, jitter) for p in all_ps],
            all_values,
            alpha=0.3,
            color=f'C{projection_type_idx}',
            zorder=1
        )
        
        # Plot mean and error bars for this batch size group
        if means:  # Only plot if we have data
            error_label = f'projection type: {projection_type}'
            axes[i].errorbar(ps, means, yerr=errors, marker='o', capsize=5, 
                        color=f'C{projection_type_idx}', zorder=2, label=error_label,
                        linewidth=2)
    
    # Set x-ticks and labels for learning rates
    all_x_ticks = []
    all_x_labels = []
    for projection_type_idx, projection_type in enumerate(projection_type_options):
        base_x = projection_type_idx * (len(learning_rates) + 1)
        all_x_ticks.extend([base_x + i for i in range(len(learning_rates))])
        all_x_labels.extend([f"{lr}" for lr in learning_rates])
    
    axes[i].set_xticks(all_x_ticks, all_x_labels, rotation=90)
    axes[i].set_xlabel('Learning Rate')
    axes[i].set_title(metric_names[i], color='black', fontsize=12)
    axes[i].grid(True)
    if i==0: axes[i].legend()

axes_lime = [(0, 1), (0, 1), (0.5, .9), (0.5, .9), (0.5, .9), (0.5, .9)]
for i, ax in enumerate(axes):
    ax.set_ylim(axes_lime[i])

plt.suptitle(f'Performance after {n_epochs} epochs of training on btbank-lite:', color='black', fontsize=14, y=0.95)
plt.tight_layout()
plt.savefig(f'analyses/exp_rproj_{random_strings[0].lower()}_spec{spec_values[0]}.pdf', bbox_inches='tight', dpi=300)
plt.show()
