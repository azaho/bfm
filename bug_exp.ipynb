# %%
import torch
import wandb, os, json
import time

from muon import Muon
from model_model import TransformerModel
from model_electrode_embedding import ElectrodeEmbedding_Learned, ElectrodeEmbedding_NoisyCoordinate, ElectrodeEmbedding_Learned_CoordinateInit, ElectrodeDataEmbeddingFFT, ElectrodeDataEmbedding

from dataset import load_dataloaders, load_subjects
from evaluation_btbench import FrozenModelEvaluation_SS_SM
from train_utils import log, update_dir_name, update_random_seed, convert_dtypes, parse_configs_from_args, get_default_configs, get_shared_memory_info

training_config, model_config, cluster_config = get_default_configs(random_string="TEMP", wandb_project="")
cluster_config['cache_subjects'] = False
dir_name = update_dir_name(model_config, training_config, cluster_config)
update_random_seed(training_config)
cluster_config['wandb_name'] = cluster_config['dir_name']
log(f"Directory name: {dir_name}", priority=0)

if len(cluster_config['wandb_project'])==0: wandb = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
log(f"Using device: {device}", priority=0)

log(f"Loading subjects...", priority=0)
all_subjects = load_subjects(training_config['train_subject_trials'], training_config['eval_subject_trials'], training_config['data_dtype'], 
                             cache=cluster_config['cache_subjects'], allow_corrupted=False)
# Out:
# [13:53:16 gpu 0.0G ram 0.6G] (0) Directory name: M_nst8_dm192_nh12_nl5_5_nCS_eaM_eeL_fb1_cls_lr0.003_rTEMP
# [13:53:16 gpu 0.0G ram 0.6G] (0) Using device: cpu
# [13:53:16 gpu 0.0G ram 0.6G] (0) Loading subjects...
# [13:53:16 gpu 0.0G ram 0.6G] (1)     loading subject btbank2...
# [13:53:16 gpu 0.0G ram 0.6G] (1)     loading subject btbank7...
# [13:53:16 gpu 0.0G ram 0.6G] (1)     loading subject btbank1...
# [13:53:16 gpu 0.0G ram 0.6G] (1)     loading subject btbank3...
# [13:53:16 gpu 0.0G ram 0.6G] (1)     loading subject btbank10...

# %%
log(f"Loading model...", priority=0)
model = TransformerModel(
    model_config['transformer']['d_model'],  
    n_layers_electrode=model_config['transformer']['n_layers_electrode'], 
    n_layers_time=model_config['transformer']['n_layers_time'],
    n_heads=model_config['transformer']['n_heads'],
    use_cls_token=model_config['transformer']['use_cls_token']
).to(device, dtype=model_config['dtype'])

if model_config['electrode_embedding']['type'] == 'learned' or model_config['electrode_embedding']['type'] == 'zero':
    electrode_embeddings = ElectrodeEmbedding_Learned(
        model_config['transformer']['d_model'], 
        embedding_dim=model_config['electrode_embedding']['embedding_dim'],
        embedding_requires_grad=model_config['electrode_embedding']['type'] != 'zero'
    )
elif model_config['electrode_embedding']['type'] == 'coordinate_init':
    electrode_embeddings = ElectrodeEmbedding_Learned_CoordinateInit(
        model_config['transformer']['d_model'], 
        embedding_dim=model_config['electrode_embedding']['embedding_dim']
    )
elif model_config['electrode_embedding']['type'] == 'noisy_coordinate':
    electrode_embeddings = ElectrodeEmbedding_NoisyCoordinate(
        model_config['transformer']['d_model'], 
        coordinate_noise_std=model_config['electrode_embedding']['coordinate_noise_std'],
        embedding_dim=model_config['electrode_embedding']['embedding_dim']
    )
else:
    raise ValueError(f"Invalid electrode embedding type: {model_config['electrode_embedding']['type']}")
electrode_embeddings = electrode_embeddings.to(device, dtype=model_config['dtype'])

if model_config['electrode_embedding']['spectrogram']:
    electrode_data_embeddings = ElectrodeDataEmbeddingFFT(
        electrode_embeddings, model_config['sample_timebin_size'], 
        max_frequency_bin=model_config['max_frequency_bin']
    ).to(device, dtype=model_config['dtype'])
else:
    electrode_data_embeddings = ElectrodeDataEmbedding(
        electrode_embeddings, model_config['sample_timebin_size'], 
        overall_sampling_rate=next(iter(all_subjects.values())).get_sampling_rate(0) # XXX remove this once figured out how to be flexible here regarding the sampling rate
    ).to(device, dtype=model_config['dtype'])

for subject in all_subjects.values():
    this_subject_trials = [trial_id for (sub_id, trial_id) in training_config['train_subject_trials'] if sub_id == subject.subject_identifier]
    electrode_data_embeddings.add_subject(subject, subject.get_sampling_rate(this_subject_trials[0]))
    log(f"Adding subject {subject.subject_identifier} to electrode data embeddings...", priority=0)
    if model_config['init_normalization']:
        for trial_id in this_subject_trials:
            log(f"Initializing normalization for subject {subject.subject_identifier} trial {trial_id}...", priority=1, indent=1)
            electrode_data_embeddings.initialize_normalization(subject, trial_id, init_normalization_window_to=int(subject.get_sampling_rate(trial_id) * 60 * 5))
electrode_data_embeddings = electrode_data_embeddings.to(device, dtype=model_config['dtype']) # moving to device again to ensure the new parameters are on the correct device

log(f"Loading dataloaders...", priority=0)
n_samples = model_config['max_n_timebins'] * model_config['sample_timebin_size']
train_dataloader, test_dataloader = load_dataloaders(
    all_subjects, training_config['train_subject_trials'], training_config['p_test'], 
    model_config['sample_timebin_size'], model_config['max_n_timebins'], training_config['data_dtype'], 
    training_config['batch_size'],
    num_workers_dataloaders=cluster_config['num_workers_dataloaders'], 
    prefetch_factor=cluster_config['prefetch_factor'],
    max_n_electrodes=model_config['max_n_electrodes'],
    output_embeddings_map=electrode_embeddings.embeddings_map
)
# Out:
# [13:53:18 gpu 0.0G ram 0.6G] (0) Loading model...
# [13:53:34 gpu 0.0G ram 0.6G] (0) Adding subject btbank2 to electrode data embeddings...
# [13:53:34 gpu 0.0G ram 0.6G] (1)     Initializing normalization for subject btbank2 trial 4...
# [13:53:39 gpu 0.0G ram 0.6G] (1)     Initializing normalization for subject btbank2 trial 5...
# [13:53:44 gpu 0.0G ram 0.6G] (0) Adding subject btbank7 to electrode data embeddings...
# [13:53:44 gpu 0.0G ram 0.6G] (1)     Initializing normalization for subject btbank7 trial 1...
# [13:53:52 gpu 0.0G ram 0.7G] (0) Adding subject btbank1 to electrode data embeddings...
# [13:53:52 gpu 0.0G ram 0.7G] (1)     Initializing normalization for subject btbank1 trial 0...
# [13:53:57 gpu 0.0G ram 0.9G] (1)     Initializing normalization for subject btbank1 trial 1...
# [13:54:02 gpu 0.0G ram 1.0G] (0) Adding subject btbank3 to electrode data embeddings...
# [13:54:02 gpu 0.0G ram 1.0G] (1)     Initializing normalization for subject btbank3 trial 1...
# [13:54:06 gpu 0.0G ram 1.1G] (1)     Initializing normalization for subject btbank3 trial 2...
# [13:54:10 gpu 0.0G ram 1.3G] (0) Adding subject btbank10 to electrode data embeddings...
# [13:54:10 gpu 0.0G ram 1.3G] (1)     Initializing normalization for subject btbank10 trial 1...
# [13:54:18 gpu 0.0G ram 1.3G] (0) Loading dataloaders...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank1_0...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank1_0
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank1_1...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank1_1
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank2_4...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank2_4
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank2_5...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank2_5
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank3_1...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank3_1
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank3_2...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank3_2
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank7_1...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank7_1
# [13:54:18 gpu 0.0G ram 1.3G] (1)     loading dataset for btbank10_1...
# [13:54:18 gpu 0.0G ram 1.3G] (1)     finished loading dataset for btbank10_1
# /net/vast-storage/scratch/vast/yanglab/zaho/bfm_ic2/.venv/lib/python3.9/site-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
batch = next(iter(train_dataloader))

batch['data'] = batch['data'].to(device, dtype=model_config['dtype'], non_blocking=True)
batch['electrode_index'] = batch['electrode_index'].to(device, dtype=torch.long, non_blocking=True)
subject_identifier, trial_id = batch['subject_trial'][0]

# %%
batch['data'].shape
# Out:
# torch.Size([100, 128, 6144])

# %%
batch['electrode_index'][0]
# Out:
# tensor([672, 710, 724, 809, 701, 761, 805, 793, 740, 667, 636, 733, 771, 829,
#         706, 644, 673, 714, 641, 631, 806, 807, 702, 817, 682, 658, 777, 779,
#         633, 790, 830, 758, 808, 781, 690, 785, 734, 699, 798, 721, 797, 812,
#         737, 727, 749, 767, 801, 694, 656, 648, 752, 831, 787, 778, 800, 736,
#         768, 735, 668, 671, 731, 713, 717, 833, 684, 662, 814, 741, 784, 747,
#         663, 834, 738, 687, 666, 757, 715, 646, 744, 630, 760, 770, 795, 745,
#         653, 764, 816, 723, 729, 722, 742, 700, 774, 775, 649, 720, 712, 728,
#         716, 827, 676, 750, 635, 654, 730, 832, 823, 765, 743, 692, 661, 659,
#         705, 677, 810, 647, 825, 645, 788, 681, 796, 769, 776, 640, 664, 783,
#         639, 804])

# %%
batch['electrode_index'][1], batch['subject_trial'][1]
# Out:
# (tensor([672, 710, 724, 809, 701, 761, 805, 793, 740, 667, 636, 733, 771, 829,
#          706, 644, 673, 714, 641, 631, 806, 807, 702, 817, 682, 658, 777, 779,
#          633, 790, 830, 758, 808, 781, 690, 785, 734, 699, 798, 721, 797, 812,
#          737, 727, 749, 767, 801, 694, 656, 648, 752, 831, 787, 778, 800, 736,
#          768, 735, 668, 671, 731, 713, 717, 833, 684, 662, 814, 741, 784, 747,
#          663, 834, 738, 687, 666, 757, 715, 646, 744, 630, 760, 770, 795, 745,
#          653, 764, 816, 723, 729, 722, 742, 700, 774, 775, 649, 720, 712, 728,
#          716, 827, 676, 750, 635, 654, 730, 832, 823, 765, 743, 692, 661, 659,
#          705, 677, 810, 647, 825, 645, 788, 681, 796, 769, 776, 640, 664, 783,
#          639, 804]),
#  ('btbank10', 1))

# %%
electrode_data_embeddings.normalization_stds.std()
# Out:
# tensor(0., dtype=torch.bfloat16, grad_fn=<StdBackward0>)

# %%
def initialize_normalization(self, subject, session_id, init_normalization_window_to=2048 * 60 * 10):
    subject_identifier = subject.subject_identifier
    indices = subject.get_electrode_indices(session_id)
    electrode_labels = subject.get_electrode_labels()
    electrode_labels = [electrode_labels[i] for i in indices]
    electrode_indices = [self.electrode_embedding_class.embeddings_map[(subject.subject_identifier, electrode_label)] for electrode_label in electrode_labels]

    with torch.no_grad():
        all_electrode_data = subject.get_all_electrode_data(session_id, window_to=init_normalization_window_to).to(self.device, dtype=self.dtype)
        electrode_means, electrode_stds = self.calculate_electrode_normalization(all_electrode_data, self.sampling_rates[electrode_indices[0]]) # XXX: Assuming all electrodes have the same sampling rate

        for idx, electrode_index in enumerate(electrode_indices):
            #print(electrode_index, electrode_means[idx], electrode_stds[idx])
            self.normalization_means.data[electrode_index] = electrode_means[idx]
            self.normalization_stds.data[electrode_index] = electrode_stds[idx]
initialize_normalization(electrode_data_embeddings, all_subjects[subject_identifier], trial_id)

# %%
electrode_data_embeddings.normalization_means
# Out:
# Parameter containing:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [9.0625, 7.8125, 7.5938,  ..., 3.4219, 3.4219, 3.4375],
#         [8.5000, 7.7188, 7.4688,  ..., 3.3438, 3.3438, 3.3594],
#         [8.9375, 7.9062, 7.5938,  ..., 3.4688, 3.4844, 3.4844]],
#        dtype=torch.bfloat16, requires_grad=True)

# %%
electrode_data_embeddings.preprocess_electrode_data(batch['data'], 2048)
# Out:
# tensor([[[[ 9.2500,  8.4375,  7.0000,  ...,  4.5625,  4.3125,  4.5625],
#           [ 9.4375,  7.4375,  7.6562,  ...,  4.3750,  4.7500,  4.5625],
#           [ 9.3750,  9.4375,  8.0000,  ...,  5.0000,  4.9375,  5.0312],
#           ...,
#           [ 9.3750,  8.5000,  7.5625,  ...,  4.0938,  4.9062,  4.8125],
#           [ 8.7500,  7.8750,  6.8125,  ...,  4.7188,  4.4688,  4.4062],
#           [ 9.6250,  8.3750,  7.7188,  ...,  4.0938,  4.0312,  4.0938]],
#
#          [[ 9.6875,  8.4375,  8.1250,  ...,  4.4375,  4.7188,  4.6562],
#           [ 7.9375,  8.3125,  7.9688,  ...,  4.3750,  4.6875,  4.5625],
#           [ 9.0000,  9.0625,  7.7188,  ...,  4.9062,  4.6875,  5.0938],
#           ...,
#           [ 7.6562,  7.3125,  8.4375,  ...,  4.1562,  4.6875,  4.8125],
#           [ 9.0625,  7.7812,  7.5000,  ...,  4.4062,  4.2500,  4.5938],
#           [ 9.9375,  8.1875,  6.8438,  ...,  4.1875,  4.1562,  4.5312]],
#
#          [[ 6.6250,  8.7500,  7.5312,  ...,  4.5000,  4.1250,  4.2500],
#           [ 9.3125,  8.4375,  7.4375,  ...,  4.2812,  4.9062,  4.6250],
#           [ 9.1250,  9.0000,  7.8438,  ...,  5.0938,  4.9062,  4.9688],
#           ...,
#           [ 7.7188,  7.9375,  8.3125,  ...,  4.4688,  4.5625,  4.7188],
#           [ 8.1250,  8.1250,  7.1250,  ...,  4.6875,  4.3438,  4.2812],
#           [ 8.6875,  8.6875,  7.5312,  ...,  4.1562,  4.3750,  4.8438]],
#
#          ...,
#
#          [[ 9.0625,  7.9688,  8.0625,  ...,  2.2031,  3.8281,  4.0000],
#           [ 8.6875,  6.9062,  6.4062,  ...,  3.7812,  4.2500,  3.6562],
#           [ 8.6875,  7.4062,  6.9375,  ...,  2.0312,  3.2812,  3.3750],
#           ...,
#           [ 7.7812,  6.8125,  7.5000,  ...,  1.3047,  3.2500,  2.8906],
#           [ 5.7188,  7.1875,  7.4688,  ...,  3.7188,  2.5156,  3.1562],
#           [ 6.6875,  7.8125,  6.6562,  ...,  3.1875,  3.1406,  3.0000]],
#
#          [[ 8.5000,  8.0625,  7.8438,  ...,  4.5000,  4.4375,  4.3750],
#           [ 9.3125,  8.0000,  8.8125,  ...,  4.2500,  4.7812,  4.6250],
#           [ 8.0000,  8.7500,  6.3438,  ...,  4.6875,  4.4375,  4.6250],
#           ...,
#           [ 7.6250,  8.8125,  8.6875,  ...,  4.5625,  4.6250,  4.7500],
#           [ 7.9375,  8.0625,  7.7188,  ...,  4.4062,  4.3438,  4.3750],
#           [ 9.0000,  8.6250,  8.1875,  ...,  4.1250,  4.7812,  4.9062]],
#
#          [[ 7.4688,  7.9062,  8.1250,  ...,  3.2500,  2.9531,  3.8438],
#           [ 8.5625,  8.2500,  7.7812,  ...,  3.7656,  3.7031,  3.9062],
#           [ 9.6250,  8.5625,  8.6875,  ...,  3.9062,  4.1875,  3.9688],
#           ...,
#           [ 7.1250,  7.8438,  8.3750,  ...,  3.7656,  3.4375,  3.7969],
#           [ 8.5625,  8.1250,  8.5000,  ...,  4.1250,  4.5625,  4.2812],
#           [ 8.1875,  8.0000,  8.9375,  ...,  4.3125,  4.4688,  3.6250]]],
#
#
#         [[[ 9.3125,  9.1875,  7.8750,  ...,  5.1250,  5.0312,  5.0938],
#           [ 8.9375,  7.8125,  8.0625,  ...,  4.6875,  4.2500,  4.8750],
#           [10.2500,  8.5625,  7.7188,  ...,  3.5625,  3.5000,  2.8438],
#           ...,
#           [ 9.6250,  8.8750,  8.2500,  ...,  3.1094,  3.1719,  3.1875],
#           [ 8.2500,  9.1875,  8.7500,  ...,  5.2188,  5.0938,  5.0000],
#           [10.8750,  9.1250,  8.4375,  ...,  4.9375,  5.1562,  4.9688]],
#
#          [[ 9.8125,  8.6250,  8.1250,  ...,  3.2031,  2.7969,  2.6094],
#           [ 9.2500,  9.0625,  7.0000,  ...,  4.3438,  4.7812,  4.6250],
#           [ 9.0000,  8.0000,  5.8125,  ...,  3.5938,  2.3125,  4.1562],
#           ...,
#           [ 7.5938,  8.6250,  7.0312,  ...,  4.5312,  4.5312,  4.4375],
#           [ 8.6875,  7.7812,  5.5000,  ...,  4.0938,  4.2500,  4.2188],
#           [ 7.6875,  7.2812,  5.6562,  ...,  4.4688,  4.5000,  4.6250]],
#
#          [[ 8.1875,  8.5000,  6.0312,  ...,  4.5000,  4.3750,  4.7500],
#           [ 8.3125,  8.5625,  7.7500,  ...,  4.0312,  4.0938,  4.2500],
#           [ 8.6875,  7.3125,  7.3125,  ...,  3.2188,  3.5312,  4.0625],
#           ...,
#           [ 6.8438,  8.0000,  6.9375,  ...,  4.0000,  4.6250,  4.2812],
#           [ 8.7500,  8.0625,  6.9062,  ...,  4.0625,  4.0312,  4.4688],
#           [ 7.0625,  7.1250,  6.3750,  ...,  4.1562,  4.4062,  4.1875]],
#
#          ...,
#
#          [[ 7.9375,  7.3750,  6.8438,  ...,  2.2031,  3.2500,  3.1562],
#           [ 8.4375,  8.3750,  7.4688,  ...,  4.2812,  3.0156,  3.6250],
#           [ 9.3125,  7.3438,  7.4688,  ...,  3.8438,  1.7578,  2.9062],
#           ...,
#           [ 8.1250,  7.0312,  6.3125,  ...,  1.5312,  3.5000,  2.3594],
#           [ 8.3750,  7.5312,  7.7500,  ...,  2.8594,  3.8594,  3.1875],
#           [ 9.0000,  6.7188,  7.7188,  ...,  3.5000,  3.7344,  3.3281]],
#
#          [[ 7.2188,  9.1875,  8.6875,  ...,  1.8203,  3.1250,  2.3438],
#           [ 9.6250,  9.4375,  8.1250,  ...,  3.8281,  4.5312,  4.5625],
#           [ 9.3750,  7.6562,  7.5938,  ...,  3.7031,  4.3125,  3.3750],
#           ...,
#           [ 9.9375,  8.9375,  8.1250,  ...,  4.1250,  3.9531,  3.9688],
#           [ 9.8125,  6.2812,  8.3125,  ...,  4.7188,  3.7969,  4.7188],
#           [10.2500,  8.1875,  8.2500,  ...,  4.9375,  4.7188,  4.8438]],
#
#          [[10.4375,  8.2500,  8.0000,  ...,  4.0312,  4.2500,  3.5156],
#           [10.0625,  8.5000,  8.8750,  ...,  4.1875,  4.2188,  4.1875],
#           [10.4375,  8.1250,  7.9062,  ...,  3.4844,  3.6562,  2.1875],
#           ...,
#           [ 9.5000,  8.0000,  6.9375,  ...,  3.7031,  4.3438,  3.8281],
#           [10.0625,  7.7188,  7.2500,  ...,  3.9219,  3.2969,  3.9062],
#           [10.0000,  8.5000,  8.5000,  ...,  2.5312,  2.4062,  3.2500]]],
#
#
#         [[[ 9.3125,  8.2500,  7.9688,  ...,  3.6250,  3.4219,  2.7031],
#           [ 9.9375,  6.5312,  7.7812,  ...,  3.5781,  3.7812,  4.5625],
#           [ 8.8750,  8.0625,  7.4688,  ...,  3.2188,  3.9375,  3.4844],
#           ...,
#           [ 9.4375,  8.9375,  8.1250,  ...,  2.8594,  3.3438,  3.1406],
#           [ 6.6250,  8.1250,  6.5000,  ...,  4.1562,  4.2812,  4.3438],
#           [10.3125,  9.3125,  8.1875,  ...,  3.9688,  4.2812,  3.7812]],
#
#          [[ 8.5000,  8.7500,  8.7500,  ...,  5.0312,  5.0312,  5.0625],
#           [ 7.1250,  7.5625,  6.6250,  ...,  4.2188,  4.0938,  4.2812],
#           [ 7.8750,  8.1875,  7.6875,  ...,  2.4219,  2.4531,  3.2500],
#           ...,
#           [ 9.1875,  8.6250,  6.7188,  ...,  3.9688,  4.2188,  4.5312],
#           [10.0625,  8.8125,  7.5625,  ...,  4.0625,  4.3750,  4.1250],
#           [ 9.9375,  8.1875,  7.2188,  ...,  4.1250,  4.3438,  4.2812]],
#
#          [[ 7.5938,  7.8750,  8.0625,  ...,  4.5625,  4.5625,  4.4688],
#           [ 8.7500,  7.6250,  7.3750,  ...,  4.1562,  3.6562,  4.4688],
#           [ 9.1875,  8.0625,  7.6562,  ...,  4.3750,  4.3125,  4.3125],
#           ...,
#           [ 9.5625,  9.0625,  7.5000,  ...,  3.5469,  4.1562,  4.1250],
#           [ 8.3125,  8.3750,  4.4062,  ...,  3.8750,  4.3438,  4.1875],
#           [ 9.5000,  8.6875,  6.9375,  ...,  2.5781,  3.4062,  3.2656]],
#
#          ...,
#
#          [[ 9.5000,  7.4375,  7.7188,  ...,  3.3125,  2.1406,  4.0625],
#           [ 9.5625,  7.9375,  5.4062,  ...,  3.5938,  2.4688,  3.9062],
#           [ 9.2500,  7.9062,  5.1250,  ...,  1.1562,  3.6250,  3.2344],
#           ...,
#           [ 7.5312,  8.5000,  7.0000,  ...,  3.0469,  3.5000,  3.6094],
#           [ 8.1250,  7.2812,  6.9375,  ...,  2.6719,  3.0625,  3.7344],
#           [ 7.8125,  8.1250,  7.2188,  ...,  2.8594,  3.4375,  2.7500]],
#
#          [[10.0625,  8.4375,  8.5625,  ...,  4.9062,  4.8125,  4.9375],
#           [ 9.6875,  7.7812,  7.0000,  ...,  3.7500,  3.2344,  4.2812],
#           [ 9.8125,  6.3438,  8.3125,  ...,  4.5000,  4.5312,  4.2188],
#           ...,
#           [ 8.5625,  7.9688,  9.1875,  ...,  3.0938,  3.6875,  4.3125],
#           [ 9.2500,  9.0625,  5.4375,  ...,  4.3438,  4.5938,  4.2812],
#           [ 8.9375,  9.2500,  8.5000,  ...,  3.4375,  4.0938,  3.5312]],
#
#          [[ 7.4062,  8.3125,  8.1875,  ...,  4.2812,  3.9844,  3.4844],
#           [ 9.3750,  8.2500,  7.5938,  ...,  3.4688,  3.9688,  4.3125],
#           [ 9.5625,  8.6250,  7.6250,  ...,  2.2188,  3.5938,  4.0938],
#           ...,
#           [ 7.2812,  8.7500,  8.0625,  ...,  3.0469,  1.6250,  2.9531],
#           [ 7.5000,  8.0000,  7.8438,  ...,  3.5469,  1.8828,  3.8906],
#           [10.0625,  8.1250,  8.1250,  ...,  3.5938,  2.7344,  3.2031]]],
#
#
#         ...,
#
#
#         [[[ 9.1250,  8.0000,  6.8750,  ...,  4.5000,  4.3125,  4.3438],
#           [ 8.7500,  8.5625,  8.3750,  ...,  4.3125,  4.3750,  4.5625],
#           [ 9.6875,  7.9688,  7.4062,  ...,  4.7500,  4.9062,  4.9062],
#           ...,
#           [ 9.1250,  8.5625,  7.9062,  ...,  4.5312,  4.8125,  4.7812],
#           [ 8.7500,  8.5625,  4.5938,  ...,  4.5000,  4.3750,  4.2188],
#           [ 8.8750,  9.2500,  8.6250,  ...,  5.4688,  5.3125,  5.3750]],
#
#          [[ 9.5625,  6.5938,  6.7188,  ...,  4.2812,  4.3438,  4.6562],
#           [ 9.9375,  8.8750,  8.3750,  ...,  4.4375,  4.4375,  4.5312],
#           [ 7.8438,  8.8125,  8.1875,  ...,  3.9844,  4.4375,  3.7344],
#           ...,
#           [ 9.3125,  8.4375,  7.5938,  ...,  4.7188,  4.7812,  4.3438],
#           [ 9.6250,  8.5625,  8.0625,  ...,  4.5000,  4.3438,  4.1562],
#           [ 8.7500,  8.3125,  8.2500,  ...,  4.7188,  4.2500,  4.4375]],
#
#          [[ 9.0000,  7.3438,  7.4375,  ...,  4.1875,  4.2812,  4.3750],
#           [ 7.5938,  8.1875,  8.3125,  ...,  4.8750,  4.8438,  4.9375],
#           [ 8.6250,  7.9375,  7.2500,  ...,  4.5312,  4.6562,  4.5625],
#           ...,
#           [ 8.4375,  7.0938,  4.7812,  ...,  4.1875,  4.7188,  4.5938],
#           [ 4.3750,  7.6562,  6.9375,  ...,  4.4688,  4.1875,  4.1875],
#           [ 6.3438,  8.3125,  7.4375,  ...,  3.5312,  3.3594,  4.0625]],
#
#          ...,
#
#          [[ 6.8750,  7.4688,  7.2812,  ...,  3.3750,  3.1094,  2.7656],
#           [ 8.0625,  6.7812,  6.4375,  ...,  3.1094,  3.3906,  3.6875],
#           [ 7.5000,  5.5938,  6.4375,  ...,  3.0938,  2.9844,  3.1094],
#           ...,
#           [ 8.9375,  6.7500,  6.9062,  ...,  2.8906,  3.5000,  0.9453],
#           [ 6.0938,  7.0625,  7.1875,  ...,  2.9688,  2.9219,  3.7969],
#           [ 8.6875,  7.2500,  6.4375,  ...,  4.0312,  3.6719,  3.1250]],
#
#          [[ 8.8125,  8.7500,  8.5000,  ...,  5.0000,  5.0312,  5.1562],
#           [ 9.4375,  8.5625,  7.5000,  ...,  4.7812,  4.2188,  4.8438],
#           [ 6.1250,  8.6250,  8.8750,  ...,  3.5781,  4.2500,  3.7188],
#           ...,
#           [ 8.6250,  8.2500,  8.5625,  ...,  4.5625,  4.8438,  4.6875],
#           [ 9.3125,  8.3750,  8.6875,  ...,  4.2188,  4.3750,  4.3750],
#           [10.0000,  8.6250,  8.7500,  ...,  4.0312,  4.1562,  3.7031]],
#
#          [[ 8.5000,  8.3125,  8.5000,  ...,  4.1250,  4.0625,  3.4844],
#           [ 8.9375,  8.1875,  8.3750,  ...,  3.0625,  3.9688,  3.6562],
#           [ 8.1875,  7.7188,  8.3750,  ...,  2.9062,  3.1094,  3.7344],
#           ...,
#           [ 9.3750,  7.6875,  8.3125,  ...,  3.3594,  3.4688,  1.7266],
#           [ 9.1875,  8.2500,  8.2500,  ...,  3.2500,  3.6250,  3.6719],
#           [ 9.1250,  8.1250,  8.7500,  ...,  4.3438,  4.5312,  4.4062]]],
#
#
#         [[[ 8.6875,  8.8750,  7.5312,  ...,  3.6719,  2.9219,  2.0469],
#           [ 9.0000,  8.4375,  7.0625,  ...,  2.2969,  3.9375,  3.5938],
#           [10.1875,  9.0625,  8.5625,  ...,  5.3125,  5.2500,  5.2812],
#           ...,
#           [ 9.7500,  8.1250,  7.4062,  ...,  4.1562,  3.3125,  4.3125],
#           [10.2500,  7.0938,  6.9062,  ...,  3.5000,  3.7031,  4.1562],
#           [10.5625,  8.6875,  8.0625,  ...,  3.8594,  4.1250,  4.3438]],
#
#          [[10.1250,  7.9688,  7.2812,  ...,  3.8906,  4.0312,  3.3906],
#           [ 9.6875,  8.0000,  6.8750,  ...,  3.5000,  3.7656,  3.0781],
#           [ 9.9375,  7.3750,  7.1562,  ...,  3.2969,  1.8750,  2.3906],
#           ...,
#           [ 9.4375,  8.4375,  7.5625,  ...,  4.2188,  4.2500,  3.6094],
#           [ 9.4375,  8.6250,  7.5312,  ...,  4.3438,  4.7500,  4.4375],
#           [ 6.6875,  6.9375,  6.3750,  ...,  3.0938,  2.9375,  3.1875]],
#
#          [[10.0000,  7.2188,  7.2188,  ...,  4.0938,  4.0000,  3.2969],
#           [ 9.3750,  8.7500,  7.1875,  ...,  3.2188,  3.9688,  3.7812],
#           [ 8.1875,  8.5000,  7.4688,  ...,  2.4688,  3.2656,  2.5625],
#           ...,
#           [ 8.5625,  7.1250,  7.8438,  ...,  3.0000,  3.4531,  2.7812],
#           [ 8.8750,  7.8750,  7.4375,  ...,  4.0938,  3.9062,  3.4688],
#           [ 6.5938,  7.4062,  7.4688,  ...,  3.4375,  2.8125,  3.2500]],
#
#          ...,
#
#          [[ 8.7500,  6.7812,  7.0000,  ...,  2.7656,  3.2188,  3.1719],
#           [ 9.1875,  7.5000,  7.0938,  ...,  2.8125,  3.4219,  2.9531],
#           [ 8.8750,  7.8125,  7.1250,  ...,  3.3906,  2.6406,  2.8281],
#           ...,
#           [ 7.1875,  7.5000,  7.0000,  ...,  2.9219,  3.6094,  3.9219],
#           [ 7.0000,  7.3125,  7.1875,  ...,  3.0312,  3.5156,  2.5000],
#           [ 8.5000,  7.2500,  6.5625,  ...,  2.0781,  2.8594,  2.6094]],
#
#          [[10.0625,  6.8125,  8.5625,  ...,  4.2812,  3.9375,  4.1562],
#           [ 9.6875,  9.0000,  8.0625,  ...,  3.3281,  3.8594,  3.8281],
#           [ 9.7500,  9.0000,  7.8125,  ...,  4.1875,  4.7500,  4.0312],
#           ...,
#           [ 9.0625,  9.6250,  8.3125,  ...,  4.6562,  4.6875,  4.1562],
#           [ 8.4375,  8.5000,  7.4375,  ...,  3.2344,  1.8516,  2.9844],
#           [ 8.6250,  8.5000,  7.3125,  ...,  4.0312,  2.1250,  3.5625]],
#
#          [[10.3125,  7.5312,  8.3125,  ...,  4.0938,  4.4062,  4.3438],
#           [10.1875,  7.6562,  7.4062,  ...,  4.3125,  3.9688,  3.2344],
#           [10.2500,  5.4062,  6.0625,  ...,  3.2188,  3.5469,  2.5156],
#           ...,
#           [ 8.8125,  8.3750,  6.4062,  ...,  4.0938,  3.4844,  4.0000],
#           [ 7.5625,  8.7500,  7.5625,  ...,  3.3281,  3.3594,  3.4219],
#           [ 8.9375,  8.2500,  7.4375,  ...,  3.1094,  3.8906,  3.0156]]],
#
#
#         [[[10.6875,  9.3125,  8.5625,  ...,  4.5000,  4.4375,  4.2188],
#           [10.1250,  8.5000,  8.8125,  ...,  5.2500,  5.1250,  5.1875],
#           [ 9.1875,  8.4375,  6.3125,  ...,  5.0000,  4.4375,  4.5938],
#           ...,
#           [ 9.3750,  7.8125,  7.6875,  ...,  3.8750,  4.3750,  4.5312],
#           [ 9.1875,  8.5000,  6.1875,  ...,  4.5000,  4.6562,  4.9062],
#           [ 8.6875,  9.1250,  7.3125,  ...,  3.8906,  4.1875,  4.1562]],
#
#          [[10.3125,  8.1250,  8.0000,  ...,  4.3125,  3.0625,  2.9062],
#           [ 9.1875,  9.0625,  8.4375,  ...,  4.8438,  4.6875,  5.0000],
#           [ 9.2500,  8.3750,  7.7188,  ...,  4.9688,  4.7812,  4.9062],
#           ...,
#           [ 9.5625,  8.7500,  8.0625,  ...,  3.4688,  4.1250,  4.2812],
#           [ 9.1875,  6.3750,  7.5312,  ...,  4.6250,  4.4062,  4.8750],
#           [ 9.0000,  8.2500,  7.7188,  ...,  4.1875,  4.2812,  4.1250]],
#
#          [[ 7.2812,  8.0000,  6.6562,  ...,  4.1562,  4.1562,  4.5000],
#           [ 9.1875,  7.7812,  6.6562,  ...,  4.0938,  3.5312,  4.6562],
#           [ 7.0625,  6.9688,  7.3125,  ...,  4.7500,  4.6250,  4.5938],
#           ...,
#           [ 9.9375,  8.7500,  7.5625,  ...,  3.6094,  4.2500,  3.7812],
#           [ 9.5000,  8.1875,  7.5000,  ...,  4.5000,  4.4688,  4.7812],
#           [ 9.1250,  8.5625,  7.2812,  ...,  4.3750,  4.3750,  4.4375]],
#
#          ...,
#
#          [[ 8.4375,  6.1250,  5.9062,  ...,  2.4375,  3.4688,  3.6250],
#           [ 8.9375,  7.2188,  6.5312,  ...,  3.3281,  3.6250,  2.6094],
#           [ 9.5000,  7.5938,  6.9062,  ...,  2.7188,  3.9375,  2.5312],
#           ...,
#           [ 8.3750,  7.0938,  7.6250,  ...,  4.0000,  3.8594,  4.1875],
#           [ 9.2500,  7.9062,  6.7812,  ...,  3.2188,  2.8594,  3.0469],
#           [ 9.1250,  6.2500,  7.0625,  ...,  3.0625,  2.4219,  3.1094]],
#
#          [[ 7.2188,  8.5625,  8.3125,  ...,  3.2500,  3.8750,  2.5625],
#           [ 7.3438,  7.5000,  8.8125,  ...,  3.8750,  4.1562,  4.5312],
#           [ 8.8750,  8.1875,  8.1875,  ...,  4.6250,  4.5938,  4.5312],
#           ...,
#           [ 8.8750,  7.7812,  8.8125,  ...,  5.3125,  5.4062,  5.3750],
#           [ 7.7500,  7.6562,  9.0625,  ...,  4.8438,  4.9375,  5.1562],
#           [ 6.1250,  8.1250,  8.5000,  ...,  4.0000,  4.4688,  3.6406]],
#
#          [[ 8.8125,  6.9375,  8.0625,  ...,  3.9219,  4.3438,  4.5000],
#           [ 8.8125,  7.7500,  7.2188,  ...,  4.1250,  4.7188,  4.3750],
#           [ 7.3125,  8.1250,  8.0625,  ...,  3.5938,  4.0938,  3.4375],
#           ...,
#           [ 9.4375,  9.0000,  8.2500,  ...,  4.3125,  4.0312,  4.3750],
#           [10.0000,  8.1875,  6.6875,  ...,  2.4375,  2.8750,  3.5156],
#           [ 9.3750,  7.9688,  8.3750,  ...,  3.7031,  3.7344,  3.2500]]]],
#        dtype=torch.bfloat16)

# %%
electrode_embeddings.embeddings_map
# Out:
# {('btbank2', 'LT3a1'): 0,
#  ('btbank2', 'LT3a2'): 1,
#  ('btbank2', 'LT3a3'): 2,
#  ('btbank2', 'LT3a4'): 3,
#  ('btbank2', 'LT3a5'): 4,
#  ('btbank2', 'LT3a6'): 5,
#  ('btbank2', 'LT3a7'): 6,
#  ('btbank2', 'LT3a8'): 7,
#  ('btbank2', 'LT3a9'): 8,
#  ('btbank2', 'LT3a10'): 9,
#  ('btbank2', 'LT2aA1'): 10,
#  ('btbank2', 'LT2aA2'): 11,
#  ('btbank2', 'LT2aA4'): 12,
#  ('btbank2', 'LT2aA5'): 13,
#  ('btbank2', 'LT2aA6'): 14,
#  ('btbank2', 'LT2aA7'): 15,
#  ('btbank2', 'LT2aA8'): 16,
#  ('btbank2', 'LT2aA9'): 17,
#  ('btbank2', 'LT2aA10'): 18,
#  ('btbank2', 'LT2aA11'): 19,
#  ('btbank2', 'LT2aA12'): 20,
#  ('btbank2', 'LT2aA13'): 21,
#  ('btbank2', 'LT2aA14'): 22,
#  ('btbank2', 'LT3bHa4'): 23,
#  ('btbank2', 'LT3bHa5'): 24,
#  ('btbank2', 'LT3bHa6'): 25,
#  ('btbank2', 'LT3bHa7'): 26,
#  ('btbank2', 'LT3bHa8'): 27,
#  ('btbank2', 'LT3bHa9'): 28,
#  ('btbank2', 'LT3bHa10'): 29,
#  ('btbank2', 'LT3bHa11'): 30,
#  ('btbank2', 'LT3bHa12'): 31,
#  ('btbank2', 'LT3bHa14'): 32,
#  ('btbank2', 'LT1bIb1'): 33,
#  ('btbank2', 'LT1bIb2'): 34,
#  ('btbank2', 'LT1bIb3'): 35,
#  ('btbank2', 'LT1bIb4'): 36,
#  ('btbank2', 'LT1bIb5'): 37,
#  ('btbank2', 'LT1bIb6'): 38,
#  ('btbank2', 'LT1bIb7'): 39,
#  ('btbank2', 'LT1bIb8'): 40,
#  ('btbank2', 'LT1bIb9'): 41,
#  ('btbank2', 'LT1bIb10'): 42,
#  ('btbank2', 'LT2b1'): 43,
#  ('btbank2', 'LT2b2'): 44,
#  ('btbank2', 'LT2b3'): 45,
#  ('btbank2', 'LT2b4'): 46,
#  ('btbank2', 'LT2b5'): 47,
#  ('btbank2', 'LT2b6'): 48,
#  ('btbank2', 'LT3cHb4'): 49,
#  ('btbank2', 'LT3cHb5'): 50,
#  ('btbank2', 'LT3cHb6'): 51,
#  ('btbank2', 'LT3cHb7'): 52,
#  ('btbank2', 'LT3cHb8'): 53,
#  ('btbank2', 'LT3cHb9'): 54,
#  ('btbank2', 'LT3cHb10'): 55,
#  ('btbank2', 'LT3cHb11'): 56,
#  ('btbank2', 'LT3cHb12'): 57,
#  ('btbank2', 'LT1c2'): 58,
#  ('btbank2', 'LT1c3'): 59,
#  ('btbank2', 'LT1c4'): 60,
#  ('btbank2', 'LT1c5'): 61,
#  ('btbank2', 'LT1c6'): 62,
#  ('btbank2', 'LT1c7'): 63,
#  ('btbank2', 'LT1c8'): 64,
#  ('btbank2', 'LT3d1'): 65,
#  ('btbank2', 'LT3d2'): 66,
#  ('btbank2', 'LT3d3'): 67,
#  ('btbank2', 'LT3d4'): 68,
#  ('btbank2', 'LT3d5'): 69,
#  ('btbank2', 'LT3d6'): 70,
#  ('btbank2', 'LT3d7'): 71,
#  ('btbank2', 'LT3d8'): 72,
#  ('btbank2', 'RT1aIa1'): 73,
#  ('btbank2', 'RT1aIa2'): 74,
#  ('btbank2', 'RT1aIa3'): 75,
#  ('btbank2', 'RT1aIa4'): 76,
#  ('btbank2', 'RT1aIa5'): 77,
#  ('btbank2', 'RT1aIa6'): 78,
#  ('btbank2', 'RT1aIa7'): 79,
#  ('btbank2', 'RT1aIa8'): 80,
#  ('btbank2', 'RT3aHa4'): 81,
#  ('btbank2', 'RT3aHa5'): 82,
#  ('btbank2', 'RT3aHa6'): 83,
#  ('btbank2', 'RT3aHa7'): 84,
#  ('btbank2', 'RT3aHa8'): 85,
#  ('btbank2', 'RT3aHa9'): 86,
#  ('btbank2', 'RT3aHa10'): 87,
#  ('btbank2', 'RT3aHa11'): 88,
#  ('btbank2', 'RT3aHa12'): 89,
#  ('btbank2', 'RT3aHa13'): 90,
#  ('btbank2', 'RT3aHa14'): 91,
#  ('btbank2', 'RT2aA1'): 92,
#  ('btbank2', 'RT2aA2'): 93,
#  ('btbank2', 'RT2aA3'): 94,
#  ('btbank2', 'RT2aA4'): 95,
#  ('btbank2', 'RT2aA5'): 96,
#  ('btbank2', 'RT2aA6'): 97,
#  ('btbank2', 'RT2aA7'): 98,
#  ('btbank2', 'RT2aA8'): 99,
#  ('btbank2', 'RT2aA9'): 100,
#  ('btbank2', 'RT2aA10'): 101,
#  ('btbank2', 'RT2b1'): 102,
#  ('btbank2', 'RT2b2'): 103,
#  ('btbank2', 'RT2b3'): 104,
#  ('btbank2', 'RT2b4'): 105,
#  ('btbank2', 'RT2b5'): 106,
#  ('btbank2', 'RT2b8'): 107,
#  ('btbank2', 'RT1bIb1'): 108,
#  ('btbank2', 'RT1bIb2'): 109,
#  ('btbank2', 'RT1bIb3'): 110,
#  ('btbank2', 'RT1bIb4'): 111,
#  ('btbank2', 'RT1bIb5'): 112,
#  ('btbank2', 'RT1bIb6'): 113,
#  ('btbank2', 'RT1bIb7'): 114,
#  ('btbank2', 'RT1bIb8'): 115,
#  ('btbank2', 'RT3bHb4'): 116,
#  ('btbank2', 'RT3bHb5'): 117,
#  ('btbank2', 'RT3bHb6'): 118,
#  ('btbank2', 'RT3bHb7'): 119,
#  ('btbank2', 'RT3bHb8'): 120,
#  ('btbank2', 'RT3bHb10'): 121,
#  ('btbank2', 'RT3bHb11'): 122,
#  ('btbank2', 'RT3bHb12'): 123,
#  ('btbank2', 'RT2c1'): 124,
#  ('btbank2', 'RT2c2'): 125,
#  ('btbank2', 'RT1c1'): 126,
#  ('btbank2', 'RT1c2'): 127,
#  ('btbank2', 'RT1c3'): 128,
#  ('btbank2', 'RT1c4'): 129,
#  ('btbank2', 'RT1c5'): 130,
#  ('btbank2', 'RT1c7'): 131,
#  ('btbank2', 'RT1c8'): 132,
#  ('btbank2', 'RT1c9'): 133,
#  ('btbank2', 'RT1c10'): 134,
#  ('btbank7', 'LT2H1'): 135,
#  ('btbank7', 'LT2H2'): 136,
#  ('btbank7', 'LT2H3'): 137,
#  ('btbank7', 'LT2H4'): 138,
#  ('btbank7', 'LT2H5'): 139,
#  ('btbank7', 'LT2H6'): 140,
#  ('btbank7', 'LT2H7'): 141,
#  ('btbank7', 'LT2H8'): 142,
#  ('btbank7', 'LT2H9'): 143,
#  ('btbank7', 'LT2H10'): 144,
#  ('btbank7', 'LT2H11'): 145,
#  ('btbank7', 'LT2H12'): 146,
#  ('btbank7', 'LT2H13'): 147,
#  ('btbank7', 'LT2H14'): 148,
#  ('btbank7', 'LT2H15'): 149,
#  ('btbank7', 'LT2H16'): 150,
#  ('btbank7', 'LT1A1'): 151,
#  ('btbank7', 'LT1A2'): 152,
#  ('btbank7', 'LT1A3'): 153,
#  ('btbank7', 'LT1A4'): 154,
#  ('btbank7', 'LT1A5'): 155,
#  ('btbank7', 'LT1A6'): 156,
#  ('btbank7', 'LT1A7'): 157,
#  ('btbank7', 'LT1A8'): 158,
#  ('btbank7', 'LT1A9'): 159,
#  ('btbank7', 'LT1A10'): 160,
#  ('btbank7', 'LT1A11'): 161,
#  ('btbank7', 'LT1A12'): 162,
#  ('btbank7', 'LT1A13'): 163,
#  ('btbank7', 'LT1A14'): 164,
#  ('btbank7', 'LF3aOFa1'): 165,
#  ('btbank7', 'LF3aOFa2'): 166,
#  ('btbank7', 'LF3aOFa3'): 167,
#  ('btbank7', 'LF3aOFa4'): 168,
#  ('btbank7', 'LF3aOFa5'): 169,
#  ('btbank7', 'LF3aOFa6'): 170,
#  ('btbank7', 'LF3aOFa7'): 171,
#  ('btbank7', 'LF3aOFa8'): 172,
#  ('btbank7', 'LF3aOFa9'): 173,
#  ('btbank7', 'LF3aOFa10'): 174,
#  ('btbank7', 'LF3aOFa11'): 175,
#  ('btbank7', 'LF3aOFa12'): 176,
#  ('btbank7', 'LF3aOFa13'): 177,
#  ('btbank7', 'LF3aOFa14'): 178,
#  ('btbank7', 'LF3aOFa15'): 179,
#  ('btbank7', 'LF3aOFa16'): 180,
#  ('btbank7', 'LF3cIc1'): 181,
#  ('btbank7', 'LF3cIc2'): 182,
#  ('btbank7', 'LF3cIc3'): 183,
#  ('btbank7', 'LF3cIc4'): 184,
#  ('btbank7', 'LF3cIc5'): 185,
#  ('btbank7', 'LF3cIc6'): 186,
#  ('btbank7', 'LF3cIc7'): 187,
#  ('btbank7', 'LF3cIc8'): 188,
#  ('btbank7', 'LF3cIc9'): 189,
#  ('btbank7', 'LF3cIc10'): 190,
#  ('btbank7', 'LF3bOFb1'): 191,
#  ('btbank7', 'LF3bOFb2'): 192,
#  ('btbank7', 'LF3bOFb3'): 193,
#  ('btbank7', 'LF3bOFb4'): 194,
#  ('btbank7', 'LF3bOFb5'): 195,
#  ('btbank7', 'LF3bOFb6'): 196,
#  ('btbank7', 'LF3bOFb7'): 197,
#  ('btbank7', 'LF3bOFb8'): 198,
#  ('btbank7', 'LF3bOFb9'): 199,
#  ('btbank7', 'LF3bOFb10'): 200,
#  ('btbank7', 'LF3bOFb11'): 201,
#  ('btbank7', 'LF3bOFb12'): 202,
#  ('btbank7', 'LF3bOFb13'): 203,
#  ('btbank7', 'LF3bOFb14'): 204,
#  ('btbank7', 'LF3bOFb15'): 205,
#  ('btbank7', 'LF3bOFb16'): 206,
#  ('btbank7', 'LF2b1'): 207,
#  ('btbank7', 'LF2b2'): 208,
#  ('btbank7', 'LF2b3'): 209,
#  ('btbank7', 'LF2b4'): 210,
#  ('btbank7', 'LF2b5'): 211,
#  ('btbank7', 'LF2b6'): 212,
#  ('btbank7', 'LF2b7'): 213,
#  ('btbank7', 'LF2b8'): 214,
#  ('btbank7', 'LF2b9'): 215,
#  ('btbank7', 'LF2b10'): 216,
#  ('btbank7', 'LF2b11'): 217,
#  ('btbank7', 'LF2b12'): 218,
#  ('btbank7', 'LF2b13'): 219,
#  ('btbank7', 'LF2b14'): 220,
#  ('btbank7', 'LF2e1'): 221,
#  ('btbank7', 'LF2e2'): 222,
#  ('btbank7', 'LF2e3'): 223,
#  ('btbank7', 'LF2e4'): 224,
#  ('btbank7', 'LF2e5'): 225,
#  ('btbank7', 'LF2e6'): 226,
#  ('btbank7', 'LF2e7'): 227,
#  ('btbank7', 'LF2e8'): 228,
#  ('btbank7', 'LF2c1'): 229,
#  ('btbank7', 'LF2c2'): 230,
#  ('btbank7', 'LF2c3'): 231,
#  ('btbank7', 'LF2c4'): 232,
#  ('btbank7', 'LF2c5'): 233,
#  ('btbank7', 'LF2c6'): 234,
#  ('btbank7', 'LF2c7'): 235,
#  ('btbank7', 'LF2c8'): 236,
#  ('btbank7', 'LF2d1'): 237,
#  ('btbank7', 'LF2d2'): 238,
#  ('btbank7', 'LF2d3'): 239,
#  ('btbank7', 'LF2d4'): 240,
#  ('btbank7', 'LF2d5'): 241,
#  ('btbank7', 'LF2d6'): 242,
#  ('btbank7', 'LF2d7'): 243,
#  ('btbank7', 'LF2d8'): 244,
#  ('btbank7', 'LF2aIa1'): 245,
#  ('btbank7', 'LF2aIa2'): 246,
#  ('btbank7', 'LF2aIa3'): 247,
#  ('btbank7', 'LF2aIa4'): 248,
#  ('btbank7', 'LF2aIa5'): 249,
#  ('btbank7', 'LF2aIa6'): 250,
#  ('btbank7', 'LF2aIa7'): 251,
#  ('btbank7', 'LF2aIa8'): 252,
#  ('btbank7', 'LF2aIa9'): 253,
#  ('btbank7', 'LF2aIa10'): 254,
#  ('btbank7', 'LF2aIa11'): 255,
#  ('btbank7', 'LF2aIa12'): 256,
#  ('btbank7', 'LF2aIa13'): 257,
#  ('btbank7', 'LF2aIa14'): 258,
#  ('btbank7', 'LF2aIa15'): 259,
#  ('btbank7', 'LF2aIa16'): 260,
#  ('btbank7', 'LF1aCaOF1'): 261,
#  ('btbank7', 'LF1aCaOF2'): 262,
#  ('btbank7', 'LF1aCaOF3'): 263,
#  ('btbank7', 'LF1aCaOF4'): 264,
#  ('btbank7', 'LF1aCaOF5'): 265,
#  ('btbank7', 'LF1aCaOF6'): 266,
#  ('btbank7', 'LF1aCaOF7'): 267,
#  ('btbank7', 'LF1aCaOF8'): 268,
#  ('btbank7', 'LF1aCaOF9'): 269,
#  ('btbank7', 'LF1aCaOF10'): 270,
#  ('btbank7', 'LF1aCaOF11'): 271,
#  ('btbank7', 'LF1aCaOF12'): 272,
#  ('btbank7', 'LF1aCaOF13'): 273,
#  ('btbank7', 'LF1aCaOF14'): 274,
#  ('btbank7', 'LF1aCaOF15'): 275,
#  ('btbank7', 'LF1aCaOF16'): 276,
#  ('btbank7', 'LF1bIb1'): 277,
#  ('btbank7', 'LF1bIb2'): 278,
#  ('btbank7', 'LF1bIb3'): 279,
#  ('btbank7', 'LF1bIb4'): 280,
#  ('btbank7', 'LF1bIb5'): 281,
#  ('btbank7', 'LF1bIb6'): 282,
#  ('btbank7', 'LF1bIb7'): 283,
#  ('btbank7', 'LF1bIb8'): 284,
#  ('btbank7', 'LF1bIb9'): 285,
#  ('btbank7', 'LF1bIb10'): 286,
#  ('btbank7', 'LF1bIb11'): 287,
#  ('btbank7', 'LF1bIb12'): 288,
#  ('btbank7', 'LF1bIb13'): 289,
#  ('btbank7', 'LF1bIb14'): 290,
#  ('btbank7', 'LF1bIb15'): 291,
#  ('btbank7', 'LF1bIb16'): 292,
#  ('btbank7', 'LF1cCb1'): 293,
#  ('btbank7', 'LF1cCb2'): 294,
#  ('btbank7', 'LF1cCb3'): 295,
#  ('btbank7', 'LF1cCb4'): 296,
#  ('btbank7', 'LF1cCb5'): 297,
#  ('btbank7', 'LF1cCb6'): 298,
#  ('btbank7', 'LF1cCb7'): 299,
#  ('btbank7', 'LF1cCb8'): 300,
#  ('btbank7', 'LF1cCb9'): 301,
#  ('btbank7', 'LF1cCb10'): 302,
#  ('btbank7', 'LF1cCb11'): 303,
#  ('btbank7', 'LF1cCb12'): 304,
#  ('btbank7', 'RF3aOFa1'): 305,
#  ('btbank7', 'RF3aOFa2'): 306,
#  ('btbank7', 'RF3aOFa3'): 307,
#  ('btbank7', 'RF3aOFa4'): 308,
#  ('btbank7', 'RF3aOFa5'): 309,
#  ('btbank7', 'RF3aOFa6'): 310,
#  ('btbank7', 'RF3aOFa7'): 311,
#  ('btbank7', 'RF3aOFa8'): 312,
#  ('btbank7', 'RF3aOFa9'): 313,
#  ('btbank7', 'RF3aOFa10'): 314,
#  ('btbank7', 'RF3aOFa11'): 315,
#  ('btbank7', 'RF3aOFa12'): 316,
#  ('btbank7', 'RF3aOFa13'): 317,
#  ('btbank7', 'RF3aOFa14'): 318,
#  ('btbank7', 'RF3aOFa15'): 319,
#  ('btbank7', 'RF3aOFa16'): 320,
#  ('btbank7', 'RF3bOFb1'): 321,
#  ('btbank7', 'RF3bOFb2'): 322,
#  ('btbank7', 'RF3bOFb3'): 323,
#  ('btbank7', 'RF3bOFb4'): 324,
#  ('btbank7', 'RF3bOFb5'): 325,
#  ('btbank7', 'RF3bOFb6'): 326,
#  ('btbank7', 'RF3bOFb7'): 327,
#  ('btbank7', 'RF3bOFb8'): 328,
#  ('btbank7', 'RF3bOFb9'): 329,
#  ('btbank7', 'RF3bOFb10'): 330,
#  ('btbank7', 'RF3bOFb11'): 331,
#  ('btbank7', 'RF3bOFb12'): 332,
#  ('btbank7', 'RF3bOFb13'): 333,
#  ('btbank7', 'RF3bOFb14'): 334,
#  ('btbank7', 'RF3bOFb15'): 335,
#  ('btbank7', 'RF3bOFb16'): 336,
#  ('btbank7', 'RF2I1'): 337,
#  ('btbank7', 'RF2I2'): 338,
#  ('btbank7', 'RF2I3'): 339,
#  ('btbank7', 'RF2I4'): 340,
#  ('btbank7', 'RF2I5'): 341,
#  ('btbank7', 'RF2I6'): 342,
#  ('btbank7', 'RF2I7'): 343,
#  ('btbank7', 'RF2I8'): 344,
#  ('btbank7', 'RF2I9'): 345,
#  ('btbank7', 'RF2I10'): 346,
#  ('btbank7', 'RF2I11'): 347,
#  ('btbank7', 'RF2I12'): 348,
#  ('btbank7', 'RF2I13'): 349,
#  ('btbank7', 'RF1aCaOF1'): 350,
#  ('btbank7', 'RF1aCaOF2'): 351,
#  ('btbank7', 'RF1aCaOF3'): 352,
#  ('btbank7', 'RF1aCaOF4'): 353,
#  ('btbank7', 'RF1aCaOF5'): 354,
#  ('btbank7', 'RF1aCaOF6'): 355,
#  ('btbank7', 'RF1aCaOF7'): 356,
#  ('btbank7', 'RF1aCaOF8'): 357,
#  ('btbank7', 'RF1aCaOF9'): 358,
#  ('btbank7', 'RF1aCaOF10'): 359,
#  ('btbank7', 'RF1aCaOF11'): 360,
#  ('btbank7', 'RF1aCaOF12'): 361,
#  ('btbank7', 'RF1aCaOF13'): 362,
#  ('btbank7', 'RF1aCaOF14'): 363,
#  ('btbank7', 'RF1aCaOF15'): 364,
#  ('btbank7', 'RF1aCaOF16'): 365,
#  ('btbank7', 'RF1bCb1'): 366,
#  ('btbank7', 'RF1bCb2'): 367,
#  ('btbank7', 'RF1bCb3'): 368,
#  ('btbank7', 'RF1bCb4'): 369,
#  ('btbank7', 'RF1bCb5'): 370,
#  ('btbank7', 'RF1bCb6'): 371,
#  ('btbank7', 'RF1bCb7'): 372,
#  ('btbank7', 'RF1bCb11'): 373,
#  ('btbank7', 'RF1bCb12'): 374,
#  ('btbank1', 'F3aOFa2'): 375,
#  ('btbank1', 'F3aOFa3'): 376,
#  ('btbank1', 'F3aOFa4'): 377,
#  ('btbank1', 'F3aOFa7'): 378,
#  ('btbank1', 'F3aOFa8'): 379,
#  ('btbank1', 'F3aOFa9'): 380,
#  ('btbank1', 'F3aOFa10'): 381,
#  ('btbank1', 'F3aOFa11'): 382,
#  ('btbank1', 'F3aOFa12'): 383,
#  ('btbank1', 'F3aOFa13'): 384,
#  ('btbank1', 'F3aOFa14'): 385,
#  ('btbank1', 'F3aOFa15'): 386,
#  ('btbank1', 'F3aOFa16'): 387,
#  ('btbank1', 'F3bIaOFb1'): 388,
#  ('btbank1', 'F3bIaOFb2'): 389,
#  ('btbank1', 'F3bIaOFb3'): 390,
#  ('btbank1', 'F3bIaOFb4'): 391,
#  ('btbank1', 'F3bIaOFb5'): 392,
#  ('btbank1', 'F3bIaOFb6'): 393,
#  ('btbank1', 'F3bIaOFb7'): 394,
#  ('btbank1', 'F3bIaOFb8'): 395,
#  ('btbank1', 'F3bIaOFb9'): 396,
#  ('btbank1', 'F3bIaOFb10'): 397,
#  ('btbank1', 'F3bIaOFb11'): 398,
#  ('btbank1', 'F3bIaOFb12'): 399,
#  ('btbank1', 'F3bIaOFb13'): 400,
#  ('btbank1', 'F3bIaOFb14'): 401,
#  ('btbank1', 'F3bIaOFb15'): 402,
#  ('btbank1', 'F3bIaOFb16'): 403,
#  ('btbank1', 'F3cId1'): 404,
#  ('btbank1', 'F3cId2'): 405,
#  ('btbank1', 'F3cId3'): 406,
#  ('btbank1', 'F3cId4'): 407,
#  ('btbank1', 'F3cId5'): 408,
#  ('btbank1', 'F3cId6'): 409,
#  ('btbank1', 'F3cId7'): 410,
#  ('btbank1', 'F3cId8'): 411,
#  ('btbank1', 'F3cId9'): 412,
#  ('btbank1', 'F3cId10'): 413,
#  ('btbank1', 'T1aIb1'): 414,
#  ('btbank1', 'T1aIb2'): 415,
#  ('btbank1', 'T1aIb3'): 416,
#  ('btbank1', 'T1aIb4'): 417,
#  ('btbank1', 'T1aIb5'): 418,
#  ('btbank1', 'T1aIb6'): 419,
#  ('btbank1', 'T1aIb7'): 420,
#  ('btbank1', 'T1aIb8'): 421,
#  ('btbank1', 'T2aA1'): 422,
#  ('btbank1', 'T2aA2'): 423,
#  ('btbank1', 'T2aA3'): 424,
#  ('btbank1', 'T2aA4'): 425,
#  ('btbank1', 'T2aA5'): 426,
#  ('btbank1', 'T2aA6'): 427,
#  ('btbank1', 'T2aA7'): 428,
#  ('btbank1', 'T2aA8'): 429,
#  ('btbank1', 'T2aA9'): 430,
#  ('btbank1', 'T2aA10'): 431,
#  ('btbank1', 'T2aA11'): 432,
#  ('btbank1', 'T2aA12'): 433,
#  ('btbank1', 'T2bHa1'): 434,
#  ('btbank1', 'T2bHa3'): 435,
#  ('btbank1', 'T2bHa4'): 436,
#  ('btbank1', 'T2bHa5'): 437,
#  ('btbank1', 'T2bHa7'): 438,
#  ('btbank1', 'T2bHa8'): 439,
#  ('btbank1', 'T2bHa9'): 440,
#  ('btbank1', 'T2bHa10'): 441,
#  ('btbank1', 'T2bHa11'): 442,
#  ('btbank1', 'T2bHa12'): 443,
#  ('btbank1', 'T2bHa13'): 444,
#  ('btbank1', 'T2bHa14'): 445,
#  ('btbank1', 'T1bIc1'): 446,
#  ('btbank1', 'T1bIc2'): 447,
#  ('btbank1', 'T1bIc3'): 448,
#  ('btbank1', 'T1bIc4'): 449,
#  ('btbank1', 'T1bIc5'): 450,
#  ('btbank1', 'T1bIc6'): 451,
#  ('btbank1', 'T1bIc7'): 452,
#  ('btbank1', 'T1bIc8'): 453,
#  ('btbank1', 'F3dIe1'): 454,
#  ('btbank1', 'F3dIe2'): 455,
#  ('btbank1', 'F3dIe3'): 456,
#  ('btbank1', 'F3dIe4'): 457,
#  ('btbank1', 'F3dIe5'): 458,
#  ('btbank1', 'F3dIe6'): 459,
#  ('btbank1', 'F3dIe7'): 460,
#  ('btbank1', 'F3dIe8'): 461,
#  ('btbank1', 'F3dIe9'): 462,
#  ('btbank1', 'F3dIe10'): 463,
#  ('btbank1', 'F3dIe14'): 464,
#  ('btbank1', 'T3aHb6'): 465,
#  ('btbank1', 'T3aHb9'): 466,
#  ('btbank1', 'T3aHb10'): 467,
#  ('btbank1', 'T3aHb12'): 468,
#  ('btbank1', 'T1cIf1'): 469,
#  ('btbank1', 'T1cIf2'): 470,
#  ('btbank1', 'T1cIf3'): 471,
#  ('btbank1', 'T1cIf4'): 472,
#  ('btbank1', 'T1cIf5'): 473,
#  ('btbank1', 'T1cIf6'): 474,
#  ('btbank1', 'T1cIf7'): 475,
#  ('btbank1', 'T1cIf8'): 476,
#  ('btbank1', 'T1cIf10'): 477,
#  ('btbank1', 'T1cIf11'): 478,
#  ('btbank1', 'T1cIf12'): 479,
#  ('btbank1', 'T1cIf13'): 480,
#  ('btbank1', 'T1cIf14'): 481,
#  ('btbank1', 'T1cIf15'): 482,
#  ('btbank1', 'T1cIf16'): 483,
#  ('btbank1', 'T2c4'): 484,
#  ('btbank1', 'T2c5'): 485,
#  ('btbank1', 'T2c6'): 486,
#  ('btbank1', 'T2c7'): 487,
#  ('btbank1', 'T2c8'): 488,
#  ('btbank1', 'T3bOT1'): 489,
#  ('btbank1', 'T3bOT2'): 490,
#  ('btbank1', 'T3bOT3'): 491,
#  ('btbank1', 'T3bOT4'): 492,
#  ('btbank1', 'T3bOT5'): 493,
#  ('btbank1', 'T3bOT6'): 494,
#  ('btbank1', 'T3bOT8'): 495,
#  ('btbank1', 'T3bOT9'): 496,
#  ('btbank1', 'T3bOT10'): 497,
#  ('btbank1', 'T3bOT12'): 498,
#  ('btbank1', 'T2d1'): 499,
#  ('btbank1', 'T2d2'): 500,
#  ('btbank1', 'T2d3'): 501,
#  ('btbank1', 'T2d4'): 502,
#  ('btbank1', 'T2d5'): 503,
#  ('btbank1', 'T2d6'): 504,
#  ('btbank3', 'F2Ia1'): 505,
#  ('btbank3', 'F2Ia2'): 506,
#  ('btbank3', 'F2Ia3'): 507,
#  ('btbank3', 'F2Ia4'): 508,
#  ('btbank3', 'F2Ia5'): 509,
#  ('btbank3', 'F2Ia6'): 510,
#  ('btbank3', 'F2Ia7'): 511,
#  ('btbank3', 'F2Ia8'): 512,
#  ('btbank3', 'F2Ia9'): 513,
#  ('btbank3', 'F2Ia10'): 514,
#  ('btbank3', 'F2Ia11'): 515,
#  ('btbank3', 'F2Ia12'): 516,
#  ('btbank3', 'F2Ia13'): 517,
#  ('btbank3', 'F2Ia14'): 518,
#  ('btbank3', 'F3c1'): 519,
#  ('btbank3', 'F3c2'): 520,
#  ('btbank3', 'F3c3'): 521,
#  ('btbank3', 'F3c4'): 522,
#  ('btbank3', 'F3c5'): 523,
#  ('btbank3', 'F3c6'): 524,
#  ('btbank3', 'F3c8'): 525,
#  ('btbank3', 'F3c9'): 526,
#  ('btbank3', 'F3c10'): 527,
#  ('btbank3', 'F3b1'): 528,
#  ('btbank3', 'F3b2'): 529,
#  ('btbank3', 'F3b3'): 530,
#  ('btbank3', 'F3b4'): 531,
#  ('btbank3', 'F3b7'): 532,
#  ('btbank3', 'F3b8'): 533,
#  ('btbank3', 'F3aOF1'): 534,
#  ('btbank3', 'F3aOF2'): 535,
#  ('btbank3', 'F3aOF3'): 536,
#  ('btbank3', 'F3aOF4'): 537,
#  ('btbank3', 'F3aOF5'): 538,
#  ('btbank3', 'F3aOF6'): 539,
#  ('btbank3', 'F3aOF7'): 540,
#  ('btbank3', 'F3aOF8'): 541,
#  ('btbank3', 'F3d1'): 542,
#  ('btbank3', 'F3d2'): 543,
#  ('btbank3', 'F3d3'): 544,
#  ('btbank3', 'F3d4'): 545,
#  ('btbank3', 'F3d5'): 546,
#  ('btbank3', 'F3d6'): 547,
#  ('btbank3', 'F3d7'): 548,
#  ('btbank3', 'F3d8'): 549,
#  ('btbank3', 'F3d9'): 550,
#  ('btbank3', 'F3d10'): 551,
#  ('btbank3', 'T1aIc1'): 552,
#  ('btbank3', 'T1aIc2'): 553,
#  ('btbank3', 'T1aIc3'): 554,
#  ('btbank3', 'T1aIc4'): 555,
#  ('btbank3', 'T1aIc5'): 556,
#  ('btbank3', 'T1aIc6'): 557,
#  ('btbank3', 'P2a1'): 558,
#  ('btbank3', 'P2a2'): 559,
#  ('btbank3', 'P2a3'): 560,
#  ('btbank3', 'P2a4'): 561,
#  ('btbank3', 'P2a5'): 562,
#  ('btbank3', 'P2a6'): 563,
#  ('btbank3', 'P2a7'): 564,
#  ('btbank3', 'P2a8'): 565,
#  ('btbank3', 'P2a9'): 566,
#  ('btbank3', 'P2a10'): 567,
#  ('btbank3', 'T1b1'): 568,
#  ('btbank3', 'T1b2'): 569,
#  ('btbank3', 'T1b3'): 570,
#  ('btbank3', 'T1b4'): 571,
#  ('btbank3', 'T1b5'): 572,
#  ('btbank3', 'T1b6'): 573,
#  ('btbank3', 'T1cIe1'): 574,
#  ('btbank3', 'T1cIe2'): 575,
#  ('btbank3', 'T1cIe5'): 576,
#  ('btbank3', 'T1cIe6'): 577,
#  ('btbank3', 'T1cIe7'): 578,
#  ('btbank3', 'T1cIe8'): 579,
#  ('btbank3', 'T1cIe9'): 580,
#  ('btbank3', 'T1cIe10'): 581,
#  ('btbank3', 'T1cIe11'): 582,
#  ('btbank3', 'T1cIe12'): 583,
#  ('btbank3', 'P2b1'): 584,
#  ('btbank3', 'P2b3'): 585,
#  ('btbank3', 'P2b4'): 586,
#  ('btbank3', 'P2b5'): 587,
#  ('btbank3', 'P2b6'): 588,
#  ('btbank3', 'P2b7'): 589,
#  ('btbank3', 'P2b8'): 590,
#  ('btbank3', 'P2b9'): 591,
#  ('btbank3', 'P2b10'): 592,
#  ('btbank3', 'P2b11'): 593,
#  ('btbank3', 'P2b12'): 594,
#  ('btbank3', 'P2b13'): 595,
#  ('btbank3', 'P2b14'): 596,
#  ('btbank3', 'P2b15'): 597,
#  ('btbank3', 'P2b16'): 598,
#  ('btbank3', 'O1aIb1'): 599,
#  ('btbank3', 'O1aIb2'): 600,
#  ('btbank3', 'O1aIb3'): 601,
#  ('btbank3', 'O1aIb4'): 602,
#  ('btbank3', 'O1aIb5'): 603,
#  ('btbank3', 'O1aIb6'): 604,
#  ('btbank3', 'O1aIb7'): 605,
#  ('btbank3', 'O1aIb8'): 606,
#  ('btbank3', 'O1aIb9'): 607,
#  ('btbank3', 'O1aIb10'): 608,
#  ('btbank3', 'O1aIb11'): 609,
#  ('btbank3', 'O1aIb12'): 610,
#  ('btbank3', 'O1aIb13'): 611,
#  ('btbank3', 'O1aIb14'): 612,
#  ('btbank3', 'O1aIb15'): 613,
#  ('btbank3', 'O1aIb16'): 614,
#  ('btbank3', 'O1bId1'): 615,
#  ('btbank3', 'O1bId2'): 616,
#  ('btbank3', 'O1bId3'): 617,
#  ('btbank3', 'O1bId4'): 618,
#  ('btbank3', 'O1bId5'): 619,
#  ('btbank3', 'O1bId8'): 620,
#  ('btbank3', 'O1bId9'): 621,
#  ('btbank3', 'O1bId10'): 622,
#  ('btbank3', 'O1bId11'): 623,
#  ('btbank3', 'O1bId12'): 624,
#  ('btbank3', 'O1bId13'): 625,
#  ('btbank3', 'O1bId14'): 626,
#  ('btbank3', 'O1bId15'): 627,
#  ('btbank3', 'O1bId16'): 628,
#  ('btbank10', 'T2bH1'): 629,
#  ('btbank10', 'T2bH2'): 630,
#  ('btbank10', 'T2bH4'): 631,
#  ('btbank10', 'T2bH5'): 632,
#  ('btbank10', 'T2bH6'): 633,
#  ('btbank10', 'T2bH7'): 634,
#  ('btbank10', 'T2bH8'): 635,
#  ('btbank10', 'T2bH9'): 636,
#  ('btbank10', 'T2bH10'): 637,
#  ('btbank10', 'T2bH11'): 638,
#  ('btbank10', 'T2bH12'): 639,
#  ('btbank10', 'T2bH13'): 640,
#  ('btbank10', 'T2bH14'): 641,
#  ('btbank10', 'T2bH15'): 642,
#  ('btbank10', 'T2bH16'): 643,
#  ('btbank10', 'T2aA1'): 644,
#  ('btbank10', 'T2aA2'): 645,
#  ('btbank10', 'T2aA3'): 646,
#  ('btbank10', 'T2aA4'): 647,
#  ('btbank10', 'T2aA7'): 648,
#  ('btbank10', 'T2aA8'): 649,
#  ('btbank10', 'T2aA9'): 650,
#  ('btbank10', 'T2aA10'): 651,
#  ('btbank10', 'T2aA11'): 652,
#  ('btbank10', 'T2aA12'): 653,
#  ('btbank10', 'T2aA13'): 654,
#  ('btbank10', 'T2aA14'): 655,
#  ('btbank10', 'T1cIf1'): 656,
#  ('btbank10', 'T1cIf2'): 657,
#  ('btbank10', 'T1cIf3'): 658,
#  ('btbank10', 'T1cIf4'): 659,
#  ('btbank10', 'T1cIf5'): 660,
#  ('btbank10', 'T1cIf6'): 661,
#  ('btbank10', 'T1cIf7'): 662,
#  ('btbank10', 'T1cIf8'): 663,
#  ('btbank10', 'T1cIf9'): 664,
#  ('btbank10', 'T1cIf10'): 665,
#  ('btbank10', 'T1cIf11'): 666,
#  ('btbank10', 'T1cIf12'): 667,
#  ('btbank10', 'T1bId1'): 668,
#  ('btbank10', 'T1bId2'): 669,
#  ('btbank10', 'T1bId3'): 670,
#  ('btbank10', 'T1bId4'): 671,
#  ('btbank10', 'T1bId5'): 672,
#  ('btbank10', 'T1bId6'): 673,
#  ('btbank10', 'T1bId7'): 674,
#  ('btbank10', 'T1bId8'): 675,
#  ('btbank10', 'T1bId9'): 676,
#  ('btbank10', 'T1bId10'): 677,
#  ('btbank10', 'T1aIa1'): 678,
#  ('btbank10', 'T1aIa2'): 679,
#  ('btbank10', 'T1aIa3'): 680,
#  ('btbank10', 'T1aIa4'): 681,
#  ('btbank10', 'T1aIa5'): 682,
#  ('btbank10', 'T1aIa6'): 683,
#  ('btbank10', 'T1aIa7'): 684,
#  ('btbank10', 'T1aIa8'): 685,
#  ('btbank10', 'T1aIa9'): 686,
#  ('btbank10', 'T1aIa10'): 687,
#  ('btbank10', 'P2cCc1'): 688,
#  ('btbank10', 'P2cCc2'): 689,
#  ('btbank10', 'P2cCc3'): 690,
#  ('btbank10', 'P2cCc4'): 691,
#  ('btbank10', 'P2cCc5'): 692,
#  ('btbank10', 'P2cCc6'): 693,
#  ('btbank10', 'P2cCc7'): 694,
#  ('btbank10', 'P2cCc8'): 695,
#  ('btbank10', 'P2cCc9'): 696,
#  ('btbank10', 'P2cCc10'): 697,
#  ('btbank10', 'P2cCc11'): 698,
#  ('btbank10', 'P2cCc12'): 699,
#  ('btbank10', 'P2cCc13'): 700,
#  ('btbank10', 'P2cCc14'): 701,
#  ('btbank10', 'P2cCc15'): 702,
#  ('btbank10', 'P2aIe1'): 703,
#  ('btbank10', 'P2aIe2'): 704,
#  ('btbank10', 'P2aIe3'): 705,
#  ('btbank10', 'P2aIe4'): 706,
#  ('btbank10', 'P2aIe5'): 707,
#  ('btbank10', 'P2aIe6'): 708,
#  ('btbank10', 'P2aIe7'): 709,
#  ('btbank10', 'P2aIe8'): 710,
#  ('btbank10', 'P2aIe9'): 711,
#  ('btbank10', 'P2aIe10'): 712,
#  ('btbank10', 'P2aIe11'): 713,
#  ('btbank10', 'P2aIe12'): 714,
#  ('btbank10', 'F3cIc1'): 715,
#  ('btbank10', 'F3cIc2'): 716,
#  ('btbank10', 'F3cIc3'): 717,
#  ('btbank10', 'F3cIc4'): 718,
#  ('btbank10', 'F3cIc5'): 719,
#  ('btbank10', 'F3cIc6'): 720,
#  ('btbank10', 'F3cIc7'): 721,
#  ('btbank10', 'F3cIc8'): 722,
#  ('btbank10', 'F3cIc9'): 723,
#  ('btbank10', 'F3cIc10'): 724,
#  ('btbank10', 'F3bIb1'): 725,
#  ('btbank10', 'F3bIb2'): 726,
#  ('btbank10', 'F3bIb3'): 727,
#  ('btbank10', 'F3bIb4'): 728,
#  ('btbank10', 'F3bIb5'): 729,
#  ('btbank10', 'F3bIb6'): 730,
#  ('btbank10', 'F3bIb7'): 731,
#  ('btbank10', 'F3bIb8'): 732,
#  ('btbank10', 'F3bIb9'): 733,
#  ('btbank10', 'F3bIb10'): 734,
#  ('btbank10', 'F3aOFc1'): 735,
#  ('btbank10', 'F3aOFc2'): 736,
#  ('btbank10', 'F3aOFc3'): 737,
#  ('btbank10', 'F3aOFc4'): 738,
#  ('btbank10', 'F3aOFc5'): 739,
#  ('btbank10', 'F3aOFc6'): 740,
#  ('btbank10', 'F3aOFc7'): 741,
#  ('btbank10', 'F3aOFc8'): 742,
#  ('btbank10', 'F3aOFc9'): 743,
#  ('btbank10', 'F3aOFc10'): 744,
#  ('btbank10', 'F3aOFc11'): 745,
#  ('btbank10', 'F3aOFc12'): 746,
#  ('btbank10', 'F3aOFc13'): 747,
#  ('btbank10', 'F3aOFc14'): 748,
#  ('btbank10', 'F3aOFc15'): 749,
#  ('btbank10', 'F3aOFc16'): 750,
#  ('btbank10', 'P2bIg2'): 751,
#  ('btbank10', 'P2bIg3'): 752,
#  ('btbank10', 'P2bIg4'): 753,
#  ('btbank10', 'P2bIg5'): 754,
#  ('btbank10', 'P2bIg6'): 755,
#  ('btbank10', 'P2bIg7'): 756,
#  ('btbank10', 'P2bIg8'): 757,
#  ('btbank10', 'P2bIg9'): 758,
#  ('btbank10', 'P2bIg10'): 759,
#  ('btbank10', 'P2bIg11'): 760,
#  ('btbank10', 'P2bIg12'): 761,
#  ('btbank10', 'F2e1'): 762,
#  ('btbank10', 'F2e2'): 763,
#  ('btbank10', 'F2e3'): 764,
#  ('btbank10', 'F2e4'): 765,
#  ('btbank10', 'F2e5'): 766,
#  ('btbank10', 'F2e6'): 767,
#  ('btbank10', 'F2e7'): 768,
#  ('btbank10', 'F2e8'): 769,
#  ('btbank10', 'F2c1'): 770,
#  ('btbank10', 'F2c2'): 771,
#  ('btbank10', 'F2c3'): 772,
#  ('btbank10', 'F2c4'): 773,
#  ('btbank10', 'F2c5'): 774,
#  ('btbank10', 'F2c6'): 775,
#  ('btbank10', 'F2c7'): 776,
#  ('btbank10', 'F2c8'): 777,
#  ('btbank10', 'F2aOFb1'): 778,
#  ('btbank10', 'F2aOFb2'): 779,
#  ('btbank10', 'F2aOFb3'): 780,
#  ('btbank10', 'F2aOFb4'): 781,
#  ('btbank10', 'F2aOFb5'): 782,
#  ('btbank10', 'F2aOFb6'): 783,
#  ('btbank10', 'F2aOFb7'): 784,
#  ('btbank10', 'F2aOFb8'): 785,
#  ('btbank10', 'F2aOFb9'): 786,
#  ('btbank10', 'F2aOFb10'): 787,
#  ('btbank10', 'F2aOFb11'): 788,
#  ('btbank10', 'F2aOFb12'): 789,
#  ('btbank10', 'F2aOFb13'): 790,
#  ('btbank10', 'F2aOFb14'): 791,
#  ('btbank10', 'F2aOFb15'): 792,
#  ('btbank10', 'F2aOFb16'): 793,
#  ('btbank10', 'F2dCb1'): 794,
#  ('btbank10', 'F2dCb2'): 795,
#  ('btbank10', 'F2dCb3'): 796,
#  ('btbank10', 'F2dCb4'): 797,
#  ('btbank10', 'F2dCb5'): 798,
#  ('btbank10', 'F2dCb6'): 799,
#  ('btbank10', 'F2dCb7'): 800,
#  ('btbank10', 'F2dCb8'): 801,
#  ('btbank10', 'F2dCb9'): 802,
#  ('btbank10', 'F2dCb10'): 803,
#  ('btbank10', 'F2dCb11'): 804,
#  ('btbank10', 'F2dCb12'): 805,
#  ('btbank10', 'F2dCb13'): 806,
#  ('btbank10', 'F2dCb14'): 807,
#  ('btbank10', 'F2bCa1'): 808,
#  ('btbank10', 'F2bCa2'): 809,
#  ('btbank10', 'F2bCa3'): 810,
#  ('btbank10', 'F2bCa4'): 811,
#  ('btbank10', 'F2bCa5'): 812,
#  ('btbank10', 'F2bCa6'): 813,
#  ('btbank10', 'F2bCa7'): 814,
#  ('btbank10', 'F2bCa8'): 815,
#  ('btbank10', 'F2bCa9'): 816,
#  ('btbank10', 'F2bCa10'): 817,
#  ('btbank10', 'F2bCa11'): 818,
#  ('btbank10', 'F2bCa12'): 819,
#  ('btbank10', 'F2bCa13'): 820,
#  ('btbank10', 'F2bCa14'): 821,
#  ('btbank10', 'F2bCa15'): 822,
#  ('btbank10', 'F2bCa16'): 823,
#  ('btbank10', 'F10Fa1'): 824,
#  ('btbank10', 'F10Fa2'): 825,
#  ('btbank10', 'F10Fa3'): 826,
#  ('btbank10', 'F10Fa4'): 827,
#  ('btbank10', 'F10Fa8'): 828,
#  ('btbank10', 'F10Fa9'): 829,
#  ('btbank10', 'F10Fa10'): 830,
#  ('btbank10', 'F10Fa11'): 831,
#  ('btbank10', 'F10Fa12'): 832,
#  ('btbank10', 'F10Fa14'): 833,
#  ('btbank10', 'F10Fa15'): 834,
#  ('btbank10', 'F10Fa16'): 835}
